# %% [markdown]
# # Evaluate GPT-3 and GPT-4 for Korean sentence completions
#
# Inputs used here are formatted as one of the following.
# - Nom-Nom: Subject1-Nom Object1-Acc V. Subject2-Nom Object1-Acc
# - Nun-Nun: Subject1-Nun Object1-Acc V. Subject2-Nun Object1-Acc
# - NC-Nom: Subject2-Nom Object1-Acc
# - NC-Nun: Subject2-Nun Object1-Acc
#
# Model inserts the continuation of the second partial sentence. Then it is evaluated whether the same verb as the "context verb" (the first verb in the prompt) is repeated or negated.
#
# In the Nun-Nun condition, it is pragmatically felicitious to continue the sentence with the contrasted (negated or different) predicate from the previous sentence.

# %%
#for generation
import os
import openai

import pandas as pd
from tqdm import tqdm

# %%
#for analysis
import numpy as np
import pickle
import csv
import math
import ast

# %%
#for tokenizing Korean
from konlpy.tag import Kkma
from konlpy.utils import pprint
kkma = Kkma()

# %%
# Supply your own OpenAI API keys
keys = open('/Users/hagyeongshin/Experiments/openai-keys.txt')
lines = keys.readlines()
openai.organization = lines[0].rstrip()
openai.api_key = lines[1].rstrip()

# %%
def insert_gpt3(item):
    """
    Generate sentence continuation with GPT-3. 
    Print out the output in a dictionary format.
    """
    
    output = openai.Completion.create(
        model = "text-davinci-003",
        prompt = item,
        suffix = ".",
        max_tokens=30, 
        temperature=0, # argmax
        n= 1,
        logprobs= 1,
        stop= [".","\n"]
        )
    
    output_dict = output.to_dict()['choices'][0].to_dict()
    
    return output_dict

# %%
def insert_gpt4(item):
    """
    Generate sentence continuation with GPT-4. 
    Print out the output in a dictionary format.
    """
    
    output = openai.ChatCompletion.create(
        model = "gpt-4-0613",
        messages = [{"role": "user", "content":item}],
        max_tokens=30,
        temperature=0, #argmax
        n= 1,
        stop= [".","\n"]
        )
    
    output_dict = output.to_dict()['choices'][0].to_dict()
    
    return output_dict

# %% [markdown]
# Only GPT-3 gives the log probability of inserted tokens as of now. We are seeing here whether the context verb is contrasted or not.
#
# cverb_pos[0] is a root of the context verb.
# 1) cverb_pos[0] + VX | VXV -> negated (=contrasted)
# 2) cverb_pos[0] w/o VX | VXV -> repeated (=not contrasted)
# 3) no cverb_pos[0] -> different (further annotation is needed to determine the relation)

# %%
def eval_relation(token_pos, cverb_pos):
    """
    Determine whether the model generated the same, 
    negated or different verb than the context verb. 
    
    'contrasted': context verb root with negation
    'repeated': context verb root
    'different': no context verb root
    """
    
    relation = ''
    
    for i in range(len(token_pos)):
        if cverb_pos[0] in token_pos and 'VX' in token_pos[i] or 'VXV' in token_pos[i]: 
            relation = 'contrasted'
            break
        elif cverb_pos[0] in token_pos and 'VX' not in token_pos[i] and 'VXV' not in token_pos[i]: 
            relation = 'repeated'
        else:    
            relation = 'different'
    return relation

# %%
def main_gpt3(filename):
    """
    Sentence continuations for each prompt given in a CSV format using GPT-3.
    Compile the output and POS tags of the created tokens into a dataframe.
    """
    
    data_path = "input/{FILE}.csv".format(FILE=filename)
    df_output = pd.read_csv(data_path)
    
    token = []
    tpos = []
    cpos = []
    rel = []
    
    with tqdm(total=df_output.shape[0]) as pbar:
        for index, row in df_output.iterrows():
        
            prompt = row['full_prompt']
            
            t = insert_gpt3(prompt)
            token.append(t['text'])
            
            token_pos = kkma.pos(t['text']) #Korean pos tagger 
            tpos.append(token_pos)
            
            cverb_pos = kkma.pos(row['context_verb'])
            cpos.append(cverb_pos)
            
            relation = eval_relation(token_pos, cverb_pos)
            rel.append(relation)
            
            pbar.update(1)
            
    df_output['token'] = token
    df_output['token_pos'] = tpos
    df_output['cverb_pos'] = cpos
    df_output['relation'] = rel

    df_output.to_csv("{TASK}_gpt3_output.csv".format(TASK=filename))
    
    return df_output

# %%
def main_gpt4(filename):
    """
    Sentence continuations for each prompt given in a CSV format using GPT-4.
    Compile the output and POS tags of the created tokens into a dataframe.
    """
    
    data_path = "input/{FILE}.csv".format(FILE=filename)
    df_output = pd.read_csv(data_path)
    
    token = []
    tpos = []
    cpos = []
    rel = []
    
    with tqdm(total=df_output.shape[0]) as pbar:
        for index, row in df_output.iterrows():
        
            prompt = row['full_prompt']
            
            t = insert_gpt4(prompt)
            token.append(t['message']['content'])
            
            token_pos = kkma.pos(t['message']['content']) #Korean pos tagger
            tpos.append(token_pos)
            
            cverb_pos = kkma.pos(row['context_verb'])
            cpos.append(cverb_pos)
            
            relation = eval_relation(token_pos, cverb_pos)
            rel.append(relation)
            
            pbar.update(1)
            
    df_output['token'] = token
    df_output['token_pos'] = tpos
    df_output['cverb_pos'] = cpos
    df_output['relation'] = rel

    df_output.to_csv("{TASK}_gpt4_output.csv".format(TASK=filename))
    
    return df_output

# %%
def main_gpt34(filename):
    """
    Sentence continuations for each prompt given in a CSV format using GPT-3 and GPT-4.
    The final dataframe compiles output from both GPT-3 and GPT-4 together a single dataframe.
    """
    
    data_path = "input/{FILE}.csv".format(FILE=filename)
    df_output = pd.read_csv(data_path)
    
    token_3 = []
    token_4 = []
    tpos_3 = []
    tpos_4 = []
    rel_3 = []
    rel_4 = []
    cpos = []
    
    with tqdm(total=df_output.shape[0]) as pbar:
        for index, row in df_output.iterrows():
        
            prompt = row['full_prompt']
            
            cverb_pos = kkma.pos(row['context_verb'])
            cpos.append(cverb_pos)
            
            t_3 = insert_gpt3(prompt)
            token_3.append(t_3['text'])
            
            token3_pos = kkma.pos(t_3['text'])
            tpos_3.append(token3_pos)
            
            relation_3 = eval_relation(token3_pos, cverb_pos)
            rel_3.append(relation_3)
            
            t_4 = insert_gpt4(prompt)
            token_4.append(t_4['message']['content'])
            
            token4_pos = kkma.pos(t_4['message']['content'])
            tpos_4.append(token4_pos)           
            
            relation_4 = eval_relation(token4_pos, cverb_pos)
            rel_4.append(relation_4)
            
            pbar.update(1)
            
    df_output['cverb_pos'] = cpos
    df_output['token_gpt3'] = token_3    
    df_output['token_gpt3_pos'] = tpos_3
    df_output['relation_gpt3'] = rel_3
    df_output['token_gpt4'] = token_4
    df_output['token_gpt4_pos'] = tpos_4
    df_output['relation_gpt4'] = rel_4

    df_output.to_csv("{TASK}_gpt34_output.csv".format(TASK=filename))
    
    return df_output

# %%
output = main_gpt34('subj-insert-sample')
# Out:
# 100%|█████████████████████████████████████████████| 4/4 [00:14<00:00,  3.52s/it]

# %%
output = main_gpt34('subj-insert-full')
# Out:
# 100%|█████████████████████████████████████████| 112/112 [05:32<00:00,  2.97s/it]

# %%
#output = pd.read_csv('subj-insert-full_gpt34_output.csv')

# %%
pd.set_option('display.max_rows', 500)
output
# Out:
#      item_id  scenario_id condition  \
# 0          1            1    nc-nom
# 1          2            2    nc-nom
# 2          3            3    nc-nom
# 3          4            4    nc-nom
# 4          5            5    nc-nom
# 5          6            6    nc-nom
# 6          7            7    nc-nom
# 7          8            8    nc-nom
# 8          9            9    nc-nom
# 9         10           10    nc-nom
# 10        11           11    nc-nom
# 11        12           12    nc-nom
# 12        13           13    nc-nom
# 13        14           14    nc-nom
# 14        15           15    nc-nom
# 15        16           16    nc-nom
# 16        17           17    nc-nom
# 17        18           18    nc-nom
# 18        19           19    nc-nom
# 19        20           20    nc-nom
# 20        21           21    nc-nom
# 21        22           22    nc-nom
# 22        23           23    nc-nom
# 23        24           24    nc-nom
# 24        25           25    nc-nom
# 25        26           26    nc-nom
# 26        27           27    nc-nom
# 27        28           28    nc-nom
# 28        29            1    nc-nun
# 29        30            2    nc-nun
# 30        31            3    nc-nun
# 31        32            4    nc-nun
# 32        33            5    nc-nun
# 33        34            6    nc-nun
# 34        35            7    nc-nun
# 35        36            8    nc-nun
# 36        37            9    nc-nun
# 37        38           10    nc-nun
# 38        39           11    nc-nun
# 39        40           12    nc-nun
# 40        41           13    nc-nun
# 41        42           14    nc-nun
# 42        43           15    nc-nun
# 43        44           16    nc-nun
# 44        45           17    nc-nun
# 45        46           18    nc-nun
# 46        47           19    nc-nun
# 47        48           20    nc-nun
# 48        49           21    nc-nun
# 49        50           22    nc-nun
# 50        51           23    nc-nun
# 51        52           24    nc-nun
# 52        53           25    nc-nun
# 53        54           26    nc-nun
# 54        55           27    nc-nun
# 55        56           28    nc-nun
# 56        57            1   nom-nom
# 57        58            2   nom-nom
# 58        59            3   nom-nom
# 59        60            4   nom-nom
# 60        61            5   nom-nom
# 61        62            6   nom-nom
# 62        63            7   nom-nom
# 63        64            8   nom-nom
# 64        65            9   nom-nom
# 65        66           10   nom-nom
# 66        67           11   nom-nom
# 67        68           12   nom-nom
# 68        69           13   nom-nom
# 69        70           14   nom-nom
# 70        71           15   nom-nom
# 71        72           16   nom-nom
# 72        73           17   nom-nom
# 73        74           18   nom-nom
# 74        75           19   nom-nom
# 75        76           20   nom-nom
# 76        77           21   nom-nom
# 77        78           22   nom-nom
# 78        79           23   nom-nom
# 79        80           24   nom-nom
# 80        81           25   nom-nom
# 81        82           26   nom-nom
# 82        83           27   nom-nom
# 83        84           28   nom-nom
# 84        85            1   nun-nun
# 85        86            2   nun-nun
# 86        87            3   nun-nun
# 87        88            4   nun-nun
# 88        89            5   nun-nun
# 89        90            6   nun-nun
# 90        91            7   nun-nun
# 91        92            8   nun-nun
# 92        93            9   nun-nun
# 93        94           10   nun-nun
# 94        95           11   nun-nun
# 95        96           12   nun-nun
# 96        97           13   nun-nun
# 97        98           14   nun-nun
# 98        99           15   nun-nun
# 99       100           16   nun-nun
# 100      101           17   nun-nun
# 101      102           18   nun-nun
# 102      103           19   nun-nun
# 103      104           20   nun-nun
# 104      105           21   nun-nun
# 105      106           22   nun-nun
# 106      107           23   nun-nun
# 107      108           24   nun-nun
# 108      109           25   nun-nun
# 109      110           26   nun-nun
# 110      111           27   nun-nun
# 111      112           28   nun-nun
#
#                                               scenario  \
# 0    지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...
# 1    영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...
# 2    혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...
# 3    각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...
# 4    홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...
# 5    승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...
# 6    민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...
# 7    상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...
# 8    주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...
# 9    윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...
# 10   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...
# 11   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...
# 12   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...
# 13   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...
# 14   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...
# 15   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...
# 16   유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...
# 17   예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...
# 18   지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...
# 19   지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...
# 20   도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...
# 21   슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...
# 22   소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...
# 23   민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...
# 24   동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...
# 25   지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...
# 26   민우는 친구들과 함께 백화점을 쇼핑하기로 했습니다. 민우는 약속에 늦게나마 도착했지...
# 27   다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...
# 28   지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...
# 29   영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...
# 30   혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...
# 31   각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...
# 32   홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...
# 33   승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...
# 34   민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...
# 35   상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...
# 36   주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...
# 37   윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...
# 38   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...
# 39   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...
# 40   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...
# 41   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...
# 42   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...
# 43   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...
# 44   유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...
# 45   예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...
# 46   지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...
# 47   지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...
# 48   도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...
# 49   슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...
# 50   소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...
# 51   민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...
# 52   동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...
# 53   지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...
# 54   민우는 친구들과 함께 백화점을 쇼핑하기로 했습니다. 민우는 약속에 늦게나마 도착했지...
# 55   다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...
# 56   지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...
# 57   영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...
# 58   혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...
# 59   각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...
# 60   홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...
# 61   승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...
# 62   민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...
# 63   상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...
# 64   주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...
# 65   윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...
# 66   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...
# 67   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...
# 68   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...
# 69   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...
# 70   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...
# 71   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...
# 72   유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...
# 73   예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...
# 74   지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...
# 75   지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...
# 76   도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...
# 77   슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...
# 78   소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...
# 79   민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...
# 80   동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...
# 81   지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...
# 82   민우는 친구들과 함께 백화점을 쇼핑하기로 했습니다. 민우는 약속에 늦게나마 도착했지...
# 83   다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...
# 84   지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...
# 85   영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...
# 86   혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...
# 87   각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...
# 88   홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...
# 89   승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...
# 90   민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...
# 91   상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...
# 92   주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...
# 93   윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...
# 94   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...
# 95   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...
# 96   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...
# 97   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...
# 98   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...
# 99   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...
# 100  유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...
# 101  예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...
# 102  지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...
# 103  지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...
# 104  도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...
# 105  슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...
# 106  소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...
# 107  민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...
# 108  동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...
# 109  지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...
# 110  민우는 친구들과 함께 백화점을 쇼핑하기로 했습니다. 민우는 약속에 늦게나마 도착했지...
# 111  다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...
#
#                                      target  \
# 0                                  민찬이가 메달을
# 1                                  채영이가 집을
# 2                                 동준이가 음식을
# 3                             부산 신문이 비 소식을
# 4                             박상엽 사원이 계획서를
# 5                                  범수가 단서를
# 6                               태성이가 먹을 것을
# 7                                   건후가 공을
# 8                              이강호 작가가 관심을
# 9                                 은영이가 인기를
# 10                             태웅이가 만드는 법을
# 11                         박 후보가 새로운 교육정책을
# 12                                  민기가 길을
# 13                          가영이가 눈이 오는 날씨를
# 14                                성우가 제주도를
# 15                         재민이가 행사 홍보하는 일을
# 16                               민호 학생이 뜻을
# 17                                은찬이가 저녁을
# 18                                  민수가 돈을
# 19                              영철 씨가 거짓말을
# 20                             찬우 학생이 방정식을
# 21                                형수가 물고기를
# 22                                 정한이 조립을
# 23                                  소희가 돈을
# 24                                나영 씨가 술을
# 25                               진혁이가 이삿짐을
# 26                                 윤호가 신발을
# 27                               영환 씨가 문제를
# 28                                민찬이는 메달을
# 29                                 채영이는 집을
# 30                                동준이는 음식을
# 31                            부산 신문은 비 소식을
# 32                            박상엽 사원은 계획서를
# 33                                 범수는 단서를
# 34                              태성이는 먹을 것을
# 35                                  건후는 공을
# 36                             이강호 작가는 관심을
# 37                                은영이는 인기를
# 38                             태웅이는 만드는 법을
# 39                         박 후보는 새로운 교육정책을
# 40                                  민기는 길을
# 41                          가영이는 눈이 오는 날씨를
# 42                                성우는 제주도를
# 43                         재민이는 행사 홍보하는 일을
# 44                               민호 학생은 뜻을
# 45                                은찬이는 저녁을
# 46                                  민수는 돈을
# 47                              영철 씨는 거짓말을
# 48                             찬우 학생은 방정식을
# 49                                형수는 물고기를
# 50                                 정한은 조립을
# 51                                  소희는 돈을
# 52                                나영 씨는 술을
# 53                               진혁이는 이삿짐을
# 54                                 윤호는 신발을
# 55                               영환 씨는 문제를
# 56                   보미가 메달을 받았어. 민찬이가 메달을
# 57                    태환이가 집을 나왔어. 채영이가 집을
# 58                 시은이가 음식을 만들었어. 동준이가 음식을
# 59          서울 신문이 비 소식을 알렸어. 부산 신문이 비 소식을
# 60         김아름 사원이 계획서를 썼습니다. 박상엽 사원이 계획서를
# 61                    서희가 단서를 알았어. 범수가 단서를
# 62               현정이가 먹을 것을 줬어. 태성이가 먹을 것을
# 63                     혜정이가 공을 맞았어. 건후가 공을
# 64            박새롬 작가가 관심을 모았어. 이강호 작가가 관심을
# 65                   강우가 인기를 끌었어. 은영이가 인기를
# 66            지아가 만드는 법을 설명했어. 태웅이가 만드는 법을
# 67   김 후보가 새로운 교육정책을 주장했어. 박 후보가 새로운 교육정책을
# 68                      하나가 길을 찾았어. 민기가 길을
# 69      석현이가 눈이 오는 날씨를 즐겼어. 가영이가 눈이 오는 날씨를
# 70                  민지가 제주도를 떠났어. 성우가 제주도를
# 71     선미가 행사 홍보하는 일을 시켰어. 재민이가 행사 홍보하는 일을
# 72               혜령 학생이 뜻을 몰랐어요. 민호 학생이 뜻을
# 73                 수정이가 저녁을 먹었어요. 은찬이가 저녁을
# 74                       새봄이 돈을 냈어. 민수가 돈을
# 75              선희 씨가 거짓말을 믿었어. 영철 씨가 거짓말을
# 76          승연 학생이 방정식을 이해했어요. 찬우 학생이 방정식을
# 77                  다혜가 물고기를 잡았어. 형수가 물고기를
# 78                   승철이 조립을 가르쳤어. 정한이 조립을
# 79                    민수가 돈을 요구했어요. 소희가 돈을
# 80                 은호 씨가 술을 거부했어. 나영 씨가 술을
# 81               하윤이가 이삿짐을 들었어요. 진혁이가 이삿짐을
# 82                     현주가 신발을 샀어. 윤호가 신발을
# 83               지현 씨가 문제를 제기했어. 영환 씨가 문제를
# 84                   보미는 메달을 받았어. 민찬이는 메달을
# 85                    태환이는 집을 나왔어. 채영이는 집을
# 86                 시은이는 음식을 만들었어. 동준이는 음식을
# 87          서울 신문은 비 소식을 알렸어. 부산 신문은 비 소식을
# 88         김아름 사원은 계획서를 썼습니다. 박상엽 사원은 계획서를
# 89                    서희는 단서를 알았어. 범수는 단서를
# 90               현정이는 먹을 것을 줬어. 태성이는 먹을 것을
# 91                     혜정이는 공을 맞았어. 건후는 공을
# 92            박새롬 작가는 관심을 모았어. 이강호 작가는 관심을
# 93                   강우는 인기를 끌었어. 은영이는 인기를
# 94            지아는 만드는 법을 설명했어. 태웅이는 만드는 법을
# 95   김 후보는 새로운 교육정책을 주장했어. 박 후보는 새로운 교육정책을
# 96                      하나는 길을 찾았어. 민기는 길을
# 97      석현이는 눈이 오는 날씨를 즐겼어. 가영이는 눈이 오는 날씨를
# 98                  민지는 제주도를 떠났어. 성우는 제주도를
# 99     선미는 행사 홍보하는 일을 시켰어. 재민이는 행사 홍보하는 일을
# 100              혜령 학생은 뜻을 몰랐어요. 민호 학생은 뜻을
# 101                수정이는 저녁을 먹었어요. 은찬이는 저녁을
# 102                      새봄은 돈을 냈어. 민수는 돈을
# 103             선희 씨는 거짓말을 믿었어. 영철 씨는 거짓말을
# 104         승연 학생은 방정식을 이해했어요. 찬우 학생은 방정식을
# 105                 다혜는 물고기를 잡았어. 형수는 물고기를
# 106                  승철은 조립을 가르쳤어. 정한은 조립을
# 107                   민수는 돈을 요구했어요. 소희는 돈을
# 108                은호 씨는 술을 거부했어. 나영 씨는 술을
# 109              하윤이는 이삿짐을 들었어요. 진혁이는 이삿짐을
# 110                    현주는 신발을 샀어. 윤호는 신발을
# 111              지현 씨는 문제를 제기했어. 영환 씨는 문제를
#
#                                            full_prompt context_verb  \
# 0    지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...           받다
# 1    영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...          나오다
# 2    혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...          만들다
# 3    각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...          알리다
# 4    홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...           쓰다
# 5    승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...           알다
# 6    민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...           주다
# 7    상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...           맞다
# 8    주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...          모으다
# 9    윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...           끌다
# 10   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...         설명하다
# 11   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...         주장하다
# 12   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...           찾다
# 13   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...          즐기다
# 14   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...          떠나다
# 15   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...          시키다
# 16   유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...          모르다
# 17   예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...           먹다
# 18   지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...           내다
# 19   지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...           믿다
# 20   도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...         이해하다
# 21   슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...           잡다
# 22   소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...         가르치다
# 23   민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...         요구하다
# 24   동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...         거부하다
# 25   지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...           들다
# 사다
# 27   다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...         제기하다
# 28   지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...           받다
# 29   영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...          나오다
# 30   혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...          만들다
# 31   각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...          알리다
# 32   홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...           쓰다
# 33   승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...           알다
# 34   민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...           주다
# 35   상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...           맞다
# 36   주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...          모으다
# 37   윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...           끌다
# 38   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...         설명하다
# 39   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...         주장하다
# 40   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...           찾다
# 41   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...          즐기다
# 42   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...          떠나다
# 43   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...          시키다
# 44   유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...          모르다
# 45   예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...           먹다
# 46   지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...           내다
# 47   지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...           믿다
# 48   도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...         이해하다
# 49   슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...           잡다
# 50   소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...         가르치다
# 51   민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...         요구하다
# 52   동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...         거부하다
# 53   지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...           들다
# 사다
# 55   다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...         제기하다
# 56   지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...           받다
# 57   영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...          나오다
# 58   혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...          만들다
# 59   각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...          알리다
# 60   홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...           쓰다
# 61   승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...           알다
# 62   민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...           주다
# 63   상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...           맞다
# 64   주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...          모으다
# 65   윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...           끌다
# 66   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...         설명하다
# 67   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...         주장하다
# 68   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...           찾다
# 69   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...          즐기다
# 70   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...          떠나다
# 71   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...          시키다
# 72   유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...          모르다
# 73   예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...           먹다
# 74   지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...           내다
# 75   지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...           믿다
# 76   도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...         이해하다
# 77   슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...           잡다
# 78   소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...         가르치다
# 79   민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...         요구하다
# 80   동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...         거부하다
# 81   지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...           들다
# 사다
# 83   다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...         제기하다
# 84   지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...           받다
# 85   영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...          나오다
# 86   혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...          만들다
# 87   각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...          알리다
# 88   홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...           쓰다
# 89   승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...           알다
# 90   민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...           주다
# 91   상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...           맞다
# 92   주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...          모으다
# 93   윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...           끌다
# 94   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...         설명하다
# 95   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...         주장하다
# 96   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...           찾다
# 97   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...          즐기다
# 98   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...          떠나다
# 99   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...          시키다
# 100  유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...          모르다
# 101  예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...           먹다
# 102  지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...           내다
# 103  지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...           믿다
# 104  도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...         이해하다
# 105  슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...           잡다
# 106  소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...         가르치다
# 107  민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...         요구하다
# 108  동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...         거부하다
# 109  지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...           들다
# 사다
# 111  다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...         제기하다
#
#                            cverb_pos        token_gpt3  \
# 0                [(받, VV), (다, EFN)]    얻었고, 영훈이는 두 번째
# 1               [(나오, VV), (다, EFN)]    빠져서 늦게 왔고, 소연이
# 2               [(만들, VV), (다, EFN)]      준비했고, 지원이가 파
# 3               [(알리, VV), (다, EFN)]          전하고 있습니다
# 4                [(쓰, VV), (다, EFN)]     작성하고, 이승호 사원이
# 5                [(알, VV), (다, EFN)]         모두 찾아냈습니다
# 6               [(주, VXV), (다, EFN)]     기부했고, 지연이가 놀이
# 7                         [(맞닿, VV)]
# 8               [(모으, VV), (다, EFN)]              끌었어요
# 9                [(끌, VV), (다, EFN)]            많이 받았어
# 10   [(설명, NNG), (하, XSA), (다, EFN)]     설명하고 있었고, 나는
# 11   [(주장, NNG), (하, XSA), (다, EFN)]     제시했고, 이 후보가 인
# 12               [(찾, VV), (다, EFN)]
# 13              [(즐기, VV), (다, EFN)]     좋아하고, 스키를 타는
# 14              [(떠나, VV), (다, EFN)]     떠나서 서울에 살고 있습
# 15              [(시키, VV), (다, EFN)]     맡았고, 지원이가 각 부
# 16              [(모르, VV), (다, EFN)]
# 17               [(먹, VV), (다, EFN)]
# 18                        [(내달, VV)]     가져왔고, 영희는 치킨을
# 19               [(믿, VV), (다, EFN)]    한 것 같아서 당황하고 있
# 20            [(이해, NNG), (하다, NNP)]
# 21                        [(잡다, XR)]  ___ 하는 것이 너무 재밌었
# 22             [(가르치, VV), (다, EFN)]      시작했고, 영희가 마무
# 23            [(요구, NNG), (하다, NNP)]     받고 싶지 않고, 소희가
# 24   [(거부, NNG), (하, XSA), (다, EFN)]     많이 마셨는데 너무 재밌
# 25               [(들, VV), (다, EFN)]  , 소영이가 책상을 , 승현이
# 26               [(사, VV), (다, EFN)]
# 27            [(제기, NNG), (하다, NNP)]
# 28               [(받, VV), (다, EFN)]    얻었고, 영훈이는 두 번째
# 29              [(나오, VV), (다, EFN)]
# 30              [(만들, VV), (다, EFN)]     , 소연이는 파티 장소를
# 31              [(알리, VV), (다, EFN)]
# 32               [(쓰, VV), (다, EFN)]     작성하고, 김영희 사원은
# 33               [(알, VV), (다, EFN)]
# 34              [(주, VXV), (다, EFN)]     기부했고, 지연이는 장난
# 35                        [(맞닿, VV)]
# 36              [(모으, VV), (다, EFN)]
# 37               [(끌, VV), (다, EFN)]
# 38   [(설명, NNG), (하, XSA), (다, EFN)]    설명하고 있고, 소연이는
# 39   [(주장, NNG), (하, XSA), (다, EFN)]     제시했고, 이 후보는 경
# 40               [(찾, VV), (다, EFN)]     잘 찾아왔고, 영희는 아
# 41              [(즐기, VV), (다, EFN)]              좋아해요
# 42              [(떠나, VV), (다, EFN)]     떠나 서울에 살고 있고,
# 43              [(시키, VV), (다, EFN)]   , 소연이는 각 부문 준비하
# 44              [(모르, VV), (다, EFN)]
# 45               [(먹, VV), (다, EFN)]
# 46                        [(내달, VV)]      가져왔고, 영희는 맛있
# 47               [(믿, VV), (다, EFN)]           한 것 같아요
# 48            [(이해, NNG), (하다, NNP)]
# 49                        [(잡다, XR)]        ___ 개 잡았어요
# 50             [(가르치, VV), (다, EFN)]     시작하고, 영희는 마무리
# 51            [(요구, NNG), (하다, NNP)]   , 영희는 의료비를 , 민영
# 52   [(거부, NNG), (하, XSA), (다, EFN)]     잘 못 마시는 거 같았어
# 53               [(들, VV), (다, EFN)]
# 54               [(사, VV), (다, EFN)]
# 55            [(제기, NNG), (하다, NNP)]  ___ 가져왔고, 은영 씨는
# 56               [(받, VV), (다, EFN)]               받았어
# 57              [(나오, VV), (다, EFN)]
# 58              [(만들, VV), (다, EFN)]              가져왔어
# 59              [(알리, VV), (다, EFN)]
# 60               [(쓰, VV), (다, EFN)]     리뷰했고, 이승호 사원이
# 61               [(알, VV), (다, EFN)]
# 62              [(주, VXV), (다, EFN)]
# 63                        [(맞닿, VV)]
# 64              [(모으, VV), (다, EFN)]               모았어
# 65               [(끌, VV), (다, EFN)]               끌었어
# 66   [(설명, NNG), (하, XSA), (다, EFN)]     설명했고, 나는 마무리하
# 67   [(주장, NNG), (하, XSA), (다, EFN)]      주장하고 이를 실현하기
# 68               [(찾, VV), (다, EFN)]               ___
# 69              [(즐기, VV), (다, EFN)]      좋아해서 스키를 타는
# 70              [(떠나, VV), (다, EFN)]               떠났어
# 71              [(시키, VV), (다, EFN)]               시켰어
# 72              [(모르, VV), (다, EFN)]           잘 이해했어요
# 73               [(먹, VV), (다, EFN)]
# 74                        [(내달, VV)]                냈어
# 75               [(믿, VV), (다, EFN)]            믿지 않았어
# 76            [(이해, NNG), (하다, NNP)]           잘 따라갔어요
# 77                        [(잡다, XR)]               잡았어
# 78             [(가르치, VV), (다, EFN)]    하고 있었고, 나는 마무리
# 79            [(요구, NNG), (하다, NNP)]     요구하지 않고 사과만 요
# 80   [(거부, NNG), (하, XSA), (다, EFN)]          마시고 있었고,
# 81               [(들, VV), (다, EFN)]        들고 방으로 갔어요
# 82               [(사, VV), (다, EFN)]          ___ 구입했어
# 83            [(제기, NNG), (하다, NNP)]     해결하는 방법을 제시했어
# 84               [(받, VV), (다, EFN)]          ___ 가져갔어
# 85              [(나오, VV), (다, EFN)]
# 86              [(만들, VV), (다, EFN)]              가져왔어
# 87              [(알리, VV), (다, EFN)]
# 88               [(쓰, VV), (다, EFN)]     리뷰했고, 이승호 사원은
# 89               [(알, VV), (다, EFN)]
# 90              [(주, VXV), (다, EFN)]     줬고, 영준이는 장난감을
# 91                        [(맞닿, VV)]
# 92              [(모으, VV), (다, EFN)]
# 93               [(끌, VV), (다, EFN)]               끌었어
# 94   [(설명, NNG), (하, XSA), (다, EFN)]     실습했고, 나는 마무리하
# 95   [(주장, NNG), (하, XSA), (다, EFN)]     제시했고, 이 후보는 교
# 96               [(찾, VV), (다, EFN)]
# 97              [(즐기, VV), (다, EFN)]      좋아해서 스키를 타는
# 98              [(떠나, VV), (다, EFN)]     떠나지 않고 여전히 제주
# 99              [(시키, VV), (다, EFN)]               시켰어
# 100             [(모르, VV), (다, EFN)]
# 101              [(먹, VV), (다, EFN)]
# 102                       [(내달, VV)]
# 103              [(믿, VV), (다, EFN)]            믿지 않았어
# 104           [(이해, NNG), (하다, NNP)]       ___ 하고 있었어요
# 105                       [(잡다, XR)]        ___ 하고 있었어
# 106            [(가르치, VV), (다, EFN)]         하는 것을 도왔어
# 107           [(요구, NNG), (하다, NNP)]     요구하지 않고 사과만 요
# 108  [(거부, NNG), (하, XSA), (다, EFN)]
# 109              [(들, VV), (다, EFN)]             가져갔어요
# 110              [(사, VV), (다, EFN)]            ___ 했어
# 111           [(제기, NNG), (하다, NNP)]        해결하려고 노력했어
#
#                                         token_gpt3_pos relation_gpt3  \
# 0    [(얻, VV), (었, EPT), (고, ECE), (,, SP), (영, NNG...     different
# 1    [(빠지, VV), (어서, ECD), (늦, VA), (게, ECD), (오, V...     different
# 2    [(준비, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...     different
# 3           [(전하, VV), (고, ECE), (있, VXV), (습니다, EFN)]    contrasted
# 4    [(작성, NNG), (하, XSV), (고, ECE), (,, SP), (이승, ...     different
# 5         [(모두, MAG), (찾아내, VV), (었, EPT), (습니다, EFN)]     different
# 6    [(기부, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...     different
# 7                                                   []
# 8                       [(끌, VV), (었, EPT), (어요, EFN)]     different
# 9             [(많이, MAG), (받, VV), (았, EPT), (어, EFN)]     different
# 10   [(설명, NNG), (하, XSV), (고, ECE), (있었, VV), (고, ...      repeated
# 11   [(제시, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...     different
# 12                                                  []
# 13   [(좋아하, VV), (고, ECE), (,, SP), (스키, NNG), (를, ...     different
# 14   [(떠나, VV), (서, ECD), (서울, NNG), (에, JKM), (살, ...      repeated
# 15   [(맡, VV), (았, EPT), (고, ECE), (,, SP), (지원, NN...     different
# 16                                                  []
# 17                                                  []
# 18   [(가져오, VV), (았, EPT), (고, ECE), (,, SP), (영희, ...     different
# 19   [(하, VV), (ㄴ, ETD), (것, NNB), (같, VA), (아서, EC...     different
# 20                                                  []
# 21   [(___, SW), (하, VV), (는, ETD), (것, NNB), (이, J...     different
# 22   [(시작하, VV), (었, EPT), (고, ECE), (,, SP), (영희, ...     different
# 23   [(받, VV), (고, ECE), (싶, VXA), (지, ECD), (않, VX...    contrasted
# 24   [(많이, MAG), (마시, VV), (었, EPT), (는데, ECD), (너무...     different
# 25   [(,, SP), (소영이, NNG), (가, JKS), (책상, NNG), (을,...     different
# 26                                                  []
# 27                                                  []
# 28   [(얻, VV), (었, EPT), (고, ECE), (,, SP), (영, NNG...     different
# 29                                                  []
# 30   [(,, SP), (소연, NNG), (이, JKS), (늘, VV), (ㄴ, ET...     different
# 31                                                  []
# 32   [(작성, NNG), (하, XSV), (고, ECE), (,, SP), (김영희,...     different
# 33                                                  []
# 34   [(기부, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...     different
# 35                                                  []
# 36                                                  []
# 37                                                  []
# 38   [(설명, NNG), (하, XSV), (고, ECE), (있, VXV), (고, ...    contrasted
# 39   [(제시, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...     different
# 40   [(잘, MAG), (찾아오, VV), (았, EPT), (고, ECE), (,, ...     different
# 41                              [(좋아하, VV), (어요, EFN)]     different
# 42   [(떨, VV), (나, ECE), (서울, NNG), (에, JKM), (살, V...    contrasted
# 43   [(,, SP), (소연, NNG), (이, JKS), (늘, VV), (ㄴ, ET...     different
# 44                                                  []
# 45                                                  []
# 46   [(가져오, VV), (았, EPT), (고, ECE), (,, SP), (영희, ...     different
# 47   [(하, VV), (ㄴ, ETD), (것, NNB), (같, VA), (아요, EFN)]     different
# 48                                                  []
# 49   [(___, SW), (개, NNG), (잡, VV), (았, EPT), (어요, ...     different
# 50   [(시작, NNG), (하, XSV), (고, ECE), (,, SP), (영희, ...     different
# 51   [(,, SP), (영희, NNP), (는, JX), (의료비, NNG), (를, ...     different
# 52   [(잘, MAG), (못, MAG), (마시, VV), (는, ETD), (거, N...     different
# 53                                                  []
# 54                                                  []
# 55   [(___, SW), (가지, VV), (어, ECS), (오, VX), (았, E...     different
# 56                       [(받, VV), (았, EPT), (어, EFN)]      repeated
# 57                                                  []
# 58                     [(가져오, VV), (았, EPT), (어, EFN)]     different
# 59                                                  []
# 60   [(리뷰, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...     different
# 61                                                  []
# 62                                                  []
# 63                                                  []
# 64                      [(모으, VV), (았, EPT), (어, EFN)]      repeated
# 65                       [(끌, VV), (었, EPT), (어, EFN)]      repeated
# 66   [(설명, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...      repeated
# 67   [(주장, NNG), (하, XSV), (고, ECE), (이르, VV), (ㄹ, ...      repeated
# 68                                         [(___, SW)]     different
# 69   [(좋아하, VV), (어서, ECD), (스키, NNG), (를, JKO), (타...     different
# 70                      [(떠나, VV), (었, EPT), (어, EFN)]      repeated
# 71                                [(시켰, VV), (어, ECD)]     different
# 72   [(잘, MAG), (이해, NNG), (하, XSV), (었, EPT), (어요,...     different
# 73                                                  []
# 74                       [(내, VV), (었, EPT), (어, EFN)]     different
# 75   [(믿, VV), (지, ECD), (않, VXV), (았, EPT), (어, EFN)]    contrasted
# 76          [(잘, MAG), (따라가, VV), (었, EPT), (어요, EFN)]     different
# 77                       [(잡, VV), (았, EPT), (어, EFN)]     different
# 78   [(하, VV), (고, ECE), (있었, VV), (고, ECE), (,, SP...     different
# 79   [(요구, NNG), (하, XSV), (지, ECD), (않, VXV), (고, ...    contrasted
# 80   [(마시, VV), (고, ECE), (있었, VV), (고, ECE), (,, SP)]     different
# 81   [(들, VV), (고, ECE), (방, NNG), (으로, JKM), (가, V...      repeated
# 82   [(___, SW), (구입, NNG), (하, XSV), (었, EPT), (어,...     different
# 83   [(해결, NNG), (하, XSV), (는, ETD), (방법, NNG), (을,...     different
# 84          [(___, SW), (가져가, VV), (었, EPT), (어, EFN)]     different
# 85                                                  []
# 86                     [(가져오, VV), (았, EPT), (어, EFN)]     different
# 87                                                  []
# 88   [(리뷰, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...     different
# 89                                                  []
# 90   [(주, VXV), (었, EPT), (고, ECE), (,, SP), (영준, N...    contrasted
# 91                                                  []
# 92                                                  []
# 93                       [(끌, VV), (었, EPT), (어, EFN)]      repeated
# 94   [(실습, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...     different
# 95   [(제시, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...     different
# 96                                                  []
# 97   [(좋아하, VV), (어서, ECD), (스키, NNG), (를, JKO), (타...     different
# 98   [(떠나, VV), (지, ECD), (않, VXV), (고, ECE), (여전히,...    contrasted
# 99                                [(시켰, VV), (어, ECD)]     different
# 100                                                 []
# 101                                                 []
# 102                                                 []
# 103  [(믿, VV), (지, ECD), (않, VXV), (았, EPT), (어, EFN)]    contrasted
# 104  [(___, SW), (하, VV), (고, ECE), (있, VV), (었, EP...     different
# 105  [(___, SW), (하, VV), (고, ECE), (있었, VV), (어, E...     different
# 106  [(하, VV), (는, ETD), (것, NNB), (을, JKO), (돕, VV...     different
# 107  [(요구, NNG), (하, XSV), (지, ECD), (않, VXV), (고, ...    contrasted
# 108                                                 []
# 109                   [(가져가, VV), (었, EPT), (어요, EFN)]     different
# 110           [(___, SW), (하, VV), (었, EPT), (어, EFN)]     different
# 111  [(해결, NNG), (하, XSV), (려고, ECD), (노력, NNG), (하...     different
#
#                             token_gpt4  \
# 0                  딴 것은 아니지만, 모두 잘 끝냈어
# 1       방금 나갔다고 했고, 지훈이는 버스를 타고 오고 있다고
# 2            준비했고, 지은이와 선영이가 파티 장소를 준비
# 3                               전하고 있어
# 4         작성하였고, 김지은 사원이 시장조사를 담당하였습니다
# 5                     모두 찾아서 게임을 끝냈습니다
# 6                                 기부했어
# 7                   잘 차서 결국에는 게임에서 이겼어
# 8                              많이 받았어요
# 9                               많이 끌었어
# 10                 알려주고, 지은이가 재료를 준비했어
# 11          제안하며, 국민들의 적극적인 참여를 호소했습니다
# 12             잘 찾아와서 먼저 도착했고, 혜진과 지훈도
# 13                           정말 좋아하더라고
# 14                   떠나서 지금은 부산에 살고 있어
# 15             맡았고, 수민이는 장소 세팅을 담당했습니다
# 16                          완벽하게 이해했어요
# 17                          먹었는지 모르겠어요
# 18          내고, 우리는 그의 돈으로 맛있는 음식을 먹었어
# 19      하고 있다고 생각한다면서 용석이 정말 아팠는지 의심스러
# 20          잘 이해하지 못한 것 같아서 조금 걱정이 되네요
# 21                                 잡았어
# 22             시작했고, 지민이랑 세진이가 같이 도와줬어
# 23     주는 것이 아니라, 그녀의 자동차 보험사가 친구들의 병원
# 24           많이 마셔서 좀 취했고, 성진 씨는 그런 나영
# 25         차에 실어주었고, 수진이는 가구를 정리해주었습니다
# 26                  사고 싶어서 여러 가게를 돌아봤어
# 27       제기했고, 지수 씨가 그에 대한 해결책을 제안했습니다
# 28                            딴 것 같더라고
# 29      방금 나갔다고 하고, 지훈이는 버스를 타고 오고 있다고
# 30              준비했고, 지은이는 파티 장소를 준비했어
# 31                              보도했습니다
# 32        작성하였고, 김지은 사원은 시장조사를 담당하였습니다
# 33         모두 찾아내고 결론을 내렸지만, 결국 게임을 끝낸
# 34        기부했고, 지은이는 강아지 옷을, 선우는 강아지 장
# 35      잘 치지 못해 져버렸고, 종민이가 결국 게임에서 이겼어
# 36                              많이 받았어
# 37                              많이 끌었어
# 38                가장 잘 알고 있어서 반죽을 만들었어
# 39          제안하며, 젊은 세대의 미래를 위해 노력하겠다고
# 40          잘 찾아와서 벌써 도착했고, 지은이와 현우는 방
# 41                           정말 좋아하더라고
# 42                       떠나서 부산에 살고 있어
# 43               맡았고, 수민이는 장소 세팅을 담당했어
# 44                          완벽하게 이해했어요
# 45           먹었으니 배고픈 사람은 저와 아빠 두 명이에요
# 46                내고, 혜진은 맛있는 음식을 추천했어
# 47   하는 것 같다고 생각하고 있고, 수진 씨는 용석이 정말로 아
# 48                         잘 이해한 것 같아요
# 49                                 잡았어
# 50               시작했고, 지민과 세진이 함께 도와줬어
# 51         받기로 했고, 지은은 병원비를 지불하기로 했습니다
# 52           많이 마셔서 조금 취했고, 성호 씨는 재미있는
# 53         차에 실어주었고, 수진이는 가구를 정리해주었습니다
# 54                  사고, 세진은 새로운 가방을 샀어
# 55    제기하며 회의를 이끌었고, 지은 씨는 그 문제에 대한 해결
# 56                              받지 못했어
# 57                        나가려고 준비 중이라고
# 58                                 사왔어
# 59                                 전했어
# 60                             검토하였습니다
# 61                             모르고 있었어
# 62                    줬고, 지은이가 장난감을 줬어
# 63               던졌는데 혜정이가 피하지 못하고 맞았어
# 64                                 모았어
# 65                                 끌었어
# 66                                따라했어
# 67                                비판했어
# 68                                 잃었어
# 69                                싫어했어
# 70                                 떠났어
# 71                                도와줬어
# 72                               이해했어요
# 73                             먹지 않았어요
# 74                              내지 않았어
# 75                                의심했어
# 76                               풀어냈어요
# 77                              잡지 못했어
# 78                  도왔고, 지훈이는 부품을 준비했어
# 79                           요구하지 않았어요
# 80                                 마셨어
# 81                             차에 실었어요
# 82                     사려고 했는데 결국 못 샀어
# 83     해결하는 방안을 제시했고, 선미 씨는 그 방안에 대해 의
# 84                              받지 못했어
# 85          나가려고 준비 중이고, 지훈이는 아직 집에 있어
# 86                                 사왔어
# 87                             전하지 않았어
# 88                             검토하였습니다
# 89                             모르고 있었어
# 90                  줬고, 지은이는 강아지 옷을 줬어
# 91                               잘 피했어
# 92                             모으지 못했어
# 93                                몰아갔어
# 94                       따라서 케이크를 만들었어
# 95                                비판했어
# 96                 잃어버렸는데, 지금 찾아가는 중이래
# 97                                싫어했어
# 98                           그대로 살고 있어
# 99               도와주었고, 현수는 장소 정리를 맡았어
# 100                               알았어요
# 101                          아직 안 먹었어요
# 102                             내지 않았어
# 103                               의심했어
# 104                  아직 완벽하게 이해하지 못했어요
# 105                             잡지 못했어
# 106               도왔고, 지훈은 부품을 가져다 주었어
# 107                          요구하지 않았어요
# 108                                마셨어
# 109                            차에 실었어요
# 110                             사지 않았어
# 111                      해결하는 방안을 제시했어
#
#                                         token_gpt4_pos relation_gpt4
# 0    [(땋, VV), (ㄴ, ETD), (것, NNB), (은, JX), (아니, VC...     different
# 1    [(방금, MAG), (나가, VV), (었, EPT), (다고, EFN), (하,...    contrasted
# 2    [(준비, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...     different
# 3              [(전하, VV), (고, ECE), (있, VV), (어, ECD)]     different
# 4    [(작성, NNG), (하, XSV), (였, EPT), (고, ECE), (,, ...     different
# 5    [(모두, MAG), (찾, VV), (아서, ECD), (게임, NNG), (을,...     different
# 6            [(기부, NNG), (하, XSV), (었, EPT), (어, EFN)]     different
# 7    [(잘, MAG), (차, VV), (아서, ECD), (결국, NNG), (에, ...     different
# 8            [(많이, MAG), (받, VV), (았, EPT), (어요, EFN)]     different
# 9             [(많이, MAG), (끌, VV), (었, EPT), (어, EFN)]      repeated
# 10   [(알려주, VV), (고, ECE), (,, SP), (지은이, NNG), (가,...     different
# 11   [(제안, NNG), (하, XSV), (며, ECE), (,, SP), (국민, ...     different
# 12   [(잘, MAG), (찾아오, VV), (아서, ECD), (먼저, MAG), (도...     different
# 13         [(정말, MAG), (좋아하, VV), (더라, EFN), (고, JKQ)]     different
# 14   [(떠나, VV), (서, ECD), (지금, NNG), (은, JX), (부산, ...      repeated
# 15   [(맡, VV), (았, EPT), (고, ECE), (,, SP), (수민, NN...     different
# 16   [(완벽, NNG), (하, XSV), (게, ECD), (이해, NNG), (하,...     different
# 17   [(먹, VV), (었, EPT), (는지, ECS), (모르, VV), (겠, E...      repeated
# 18   [(내고, NNG), (,, SP), (우리, NP), (는, JX), (그, NP...     different
# 19   [(하, VV), (고, ECE), (있, VXV), (다고, EFN), (생각, ...    contrasted
# 20   [(잘, MAG), (이해, NNG), (하, XSV), (지, ECD), (못하,...    contrasted
# 21                       [(잡, VV), (았, EPT), (어, EFN)]     different
# 22   [(시작하, VV), (었, EPT), (고, ECE), (,, SP), (지, N...     different
# 23   [(주, VXV), (는, ETD), (것, NNB), (이, JKC), (아니, ...    contrasted
# 24   [(많이, MAG), (마시, VV), (어서, ECD), (좀, MAG), (취하...     different
# 25   [(차, NNG), (에, JKM), (싣, VV), (어, ECD), (주, VX...    contrasted
# 26   [(사, VV), (고, ECE), (싶, VXA), (어서, ECD), (여러, ...      repeated
# 27   [(제기, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...      repeated
# 28   [(땋, VV), (ㄴ, ETD), (것, NNB), (같, VA), (더라, EF...     different
# 29   [(방금, MAG), (나가, VV), (었, EPT), (다고, EFN), (하,...    contrasted
# 30   [(준비, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...     different
# 31         [(보도, NNG), (하, XSV), (었, EPT), (습니다, EFN)]     different
# 32   [(작성, NNG), (하, XSV), (였, EPT), (고, ECE), (,, ...     different
# 33   [(모두, MAG), (찾아내, VV), (고, ECE), (결론, NNG), (을...     different
# 34   [(기부, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...     different
# 35   [(잘, MAG), (치, VV), (지, ECD), (못하, VX), (어, EC...    contrasted
# 36            [(많이, MAG), (받, VV), (았, EPT), (어, EFN)]     different
# 37            [(많이, MAG), (끌, VV), (었, EPT), (어, EFN)]      repeated
# 38   [(가장, MAG), (잘, MAG), (알, VV), (고, ECE), (있, V...    contrasted
# 39   [(제안, NNG), (하, XSV), (며, ECE), (,, SP), (젊, V...     different
# 40   [(잘, MAG), (찾아오, VV), (아서, ECD), (벌써, MAG), (도...     different
# 41         [(정말, MAG), (좋아하, VV), (더라, EFN), (고, JKQ)]     different
# 42   [(떠나, VV), (서, ECD), (부산, NNG), (에, JKM), (살, ...      repeated
# 43   [(맡, VV), (았, EPT), (고, ECE), (,, SP), (수민, NN...     different
# 44   [(완벽, NNG), (하, XSV), (게, ECD), (이해, NNG), (하,...     different
# 45   [(먹, VV), (었, EPT), (으니, ECD), (배고프, VA), (ㄴ, ...      repeated
# 46   [(내고, NNG), (,, SP), (혜진, UN), (은, JX), (맛있, V...     different
# 47   [(하, VV), (는, ETD), (것, NNB), (같, VA), (다고, EF...    contrasted
# 48   [(잘, MAG), (이해, NNG), (하, XSV), (ㄴ, ETD), (것, ...      repeated
# 49                       [(잡, VV), (았, EPT), (어, EFN)]     different
# 50   [(시작하, VV), (었, EPT), (고, ECE), (,, SP), (지, N...     different
# 51   [(받, VV), (기로, ECD), (하, VV), (었, EPT), (고, EC...     different
# 52   [(많이, MAG), (마시, VV), (어서, ECD), (조금, MAG), (취...     different
# 53   [(차, NNG), (에, JKM), (싣, VV), (어, ECD), (주, VX...    contrasted
# 54   [(사고, NNG), (,, SP), (세진, NNP), (은, JX), (새, N...      repeated
# 55   [(제기, NNG), (하, XSV), (며, ECE), (회의, NNG), (를,...      repeated
# 56   [(받, VV), (지, ECD), (못하, VX), (었, EPT), (어, EFN)]    contrasted
# 57   [(나가, VV), (려고, ECD), (준비, NNG), (중, NNB), (이,...     different
# 58    [(사, VV), (아, ECS), (오, VX), (았, EPT), (어, EFN)]     different
# 59                      [(전하, VV), (었, EPT), (어, EFN)]     different
# 60         [(검토, NNG), (하, XSV), (였, EPT), (습니다, EFN)]     different
# 61            [(모르, VV), (고, ECE), (있었, VV), (어, ECD)]     different
# 62   [(주, VXV), (었, EPT), (고, ECE), (,, SP), (지은이, ...    contrasted
# 63   [(던지, VV), (었, EPT), (는데, ECD), (혜정이, UN), (가,...     different
# 64                      [(모으, VV), (았, EPT), (어, EFN)]      repeated
# 65                       [(끌, VV), (었, EPT), (어, EFN)]      repeated
# 66                     [(따라하, VV), (었, EPT), (어, EFN)]     different
# 67           [(비판, NNG), (하, XSV), (었, EPT), (어, EFN)]     different
# 68                       [(잃, VV), (었, EPT), (어, EFN)]     different
# 69                     [(싫어하, VV), (었, EPT), (어, EFN)]     different
# 70                      [(떠나, VV), (었, EPT), (어, EFN)]      repeated
# 71                     [(도와주, VV), (었, EPT), (어, EFN)]     different
# 72          [(이해, NNG), (하, XSV), (었, EPT), (어요, EFN)]     different
# 73   [(먹, VV), (지, ECD), (않, VXV), (았, EPT), (어요, E...    contrasted
# 74   [(내, VV), (지, ECD), (않, VXV), (았, EPT), (어, EFN)]    contrasted
# 75           [(의심, NNG), (하, XSV), (었, EPT), (어, EFN)]     different
# 76                    [(풀어내, VV), (었, EPT), (어요, EFN)]     different
# 77   [(잡, VV), (지, ECD), (못하, VX), (었, EPT), (어, EFN)]     different
# 78   [(돕, VV), (았, EPT), (고, ECE), (,, SP), (지, NNG...     different
# 79   [(요구, NNG), (하, XSV), (지, ECD), (않, VXV), (았, ...    contrasted
# 80                      [(마시, VV), (었, EPT), (어, EFN)]     different
# 81   [(차, NNG), (에, JKM), (싣, VV), (었, EPT), (어요, E...     different
# 82   [(사, VV), (려고, ECD), (하, VV), (었, EPT), (는데, E...      repeated
# 83   [(해결, NNG), (하, XSV), (는, ETD), (방안, NNG), (을,...     different
# 84   [(받, VV), (지, ECD), (못하, VX), (었, EPT), (어, EFN)]    contrasted
# 85   [(나가, VV), (려고, ECD), (준비, NNG), (중이, NNG), (이...     different
# 86    [(사, VV), (아, ECS), (오, VX), (았, EPT), (어, EFN)]     different
# 87   [(전하, VV), (지, ECD), (않, VXV), (았, EPT), (어, E...    contrasted
# 88         [(검토, NNG), (하, XSV), (였, EPT), (습니다, EFN)]     different
# 89            [(모르, VV), (고, ECE), (있었, VV), (어, ECD)]     different
# 90   [(주, VXV), (었, EPT), (고, ECE), (,, SP), (지은이, ...    contrasted
# 91            [(잘, MAG), (피하, VV), (었, EPT), (어, EFN)]     different
# 92   [(모으, VV), (지, ECD), (못하, VX), (었, EPT), (어, E...    contrasted
# 93                     [(몰아가, VV), (었, EPT), (어, EFN)]     different
# 94   [(따르, VV), (아서, ECD), (케이크, NNG), (를, JKO), (만...     different
# 95           [(비판, NNG), (하, XSV), (었, EPT), (어, EFN)]     different
# 96   [(잃어버리, VV), (었, EPT), (는데, ECD), (,, SP), (지금...     different
# 97                     [(싫어하, VV), (었, EPT), (어, EFN)]     different
# 98   [(그대로, MAG), (살, VV), (고, ECE), (있, VV), (어, E...     different
# 99   [(도와주, VV), (었, EPT), (고, ECE), (,, SP), (현수, ...     different
# 100                     [(알, VV), (았, EPT), (어요, EFN)]     different
# 101  [(아직, MAG), (안, MAG), (먹, VV), (었, EPT), (어요, ...      repeated
# 102  [(내, VV), (지, ECD), (않, VXV), (았, EPT), (어, EFN)]    contrasted
# 103          [(의심, NNG), (하, XSV), (었, EPT), (어, EFN)]     different
# 104  [(아직, MAG), (완벽, NNG), (하, XSV), (게, ECD), (이해...    contrasted
# 105  [(잡, VV), (지, ECD), (못하, VX), (었, EPT), (어, EFN)]     different
# 106  [(돕, VV), (았, EPT), (고, ECE), (,, SP), (지, NNG...    contrasted
# 107  [(요구, NNG), (하, XSV), (지, ECD), (않, VXV), (았, ...    contrasted
# 108                     [(마시, VV), (었, EPT), (어, EFN)]     different
# 109  [(차, NNG), (에, JKM), (싣, VV), (었, EPT), (어요, E...     different
# 110  [(사, VV), (지, ECD), (않, VXV), (았, EPT), (어, EFN)]    contrasted
# 111  [(해결, NNG), (하, XSV), (는, ETD), (방안, NNG), (을,...     different
