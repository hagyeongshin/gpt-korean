# %% [markdown]
# # Evaluate GPT-3 for Korean sentence completions
#
# Inputs used here are formatted as one of the following.
# - Nom-Nom: Subject1-Nom Object1-Acc V. Subject2-Nom Object1-Acc
# - Nun-Nun: Subject1-Nun Object1-Acc V. Subject2-Nun Object1-Acc
# - NC-Nom: Subject2-Nom Object1-Acc
# - NC-Nun: Subject2-Nun Object1-Acc
#
# Model inserts the continuation of the second partial sentence. Probability scores for the completion is calculated.
#
# In the Nun-Nun condition, it is pragmatically felicitious to continue the sentence with the contrasted predicate from the previous sentence.

# %%
# For generation
import os
import openai

import pandas as pd
from tqdm import tqdm

# %%
# For analysis
import numpy as np
import pickle
import csv
import math
import ast
import re

# %%
# For tokenizing Korean
from konlpy.tag import Kkma
from konlpy.utils import pprint
kkma = Kkma()

# %%
# Supply your own OpenAI API keys
keys = open('../openai-keys.txt')
lines = keys.readlines()
openai.organization = lines[0].rstrip()
openai.api_key = lines[1].rstrip()

# %%
def insert_gpt3(item):
    """
    Generate sentence continuation with GPT-3. 
    Print out the output in a dictionary format.
    """
    
    output = openai.Completion.create(
        model = "text-davinci-003",
        prompt = item,
        suffix = ".",
        max_tokens = 30, 
        temperature = 0, # argmax
        n = 1,
        logprobs = 1,
        stop = ["."] 
        # Although "\n" can indicate a phrase ending, having this resulted in empty responses for several prompts.
        # Having a new line after the prompt is not technically grammatical, but it is still considered in analysis.
        )
    
    output_dict = output.to_dict()['choices'][0].to_dict()
    
    return output_dict

# %%
def inserted_prob_gpt3(experiment_item):
    """
    Generate sentence continuation with GPT-3. 
    Print out the log probability for the inserted tokens in a dictionary format.
    """
    
    output = openai.Completion.create(
        model = "text-davinci-003",
        prompt = experiment_item,
        suffix = ".",
        max_tokens = 30,
        temperature = 0,
        n = 1,
        #stream = False,
        logprobs = 1,
        stop = ["."]
        )
    
    toplogprob = output.to_dict()['choices'][0].to_dict()['logprobs'].to_dict()["top_logprobs"]
    # We are using the ["top_logprobs"] because it notes each output token and its logprob together in a JSON entry.
    # Each ["top_logprobs"] is converted into a Python dictionary: output token as a key and logprob as a value. 
    
    response = []
    
    for i in range(0,len(toplogprob)):
        response.append(toplogprob[i].to_dict())
        
    return response

# %% [markdown]
# POS tag reference: http://kkma.snu.ac.kr/documents/index.jsp?doc=postag

# %%
def eval_relation(token_pos, cverb_pos):
    """
    Determine whether the model generated the same, 
    negated or different verb than the context verb. 
    
    'contrasted': context verb root with negation
    'repeated': context verb root
    'different': no context verb root
    """
    
    relation = ''
    negation = [('안','MAG'), ('못', 'MAG'), ('않', 'VXV'), ('못하', 'VX')]
    
    if (cverb_pos[0] in token_pos) and any(neg in negation for neg in token_pos):
        relation = 'contrasted'
        
    elif (cverb_pos[0] in token_pos) and not any(neg in negation for neg in token_pos):
        relation = 'repeated'
        
    else: relation = 'different' #includes result having no verb root
        
    return relation

# %%
negation = [('안', 'MAG'), ('못', 'MAG'), ('않', 'VXV'),('못하', 'VX')]
item = [('안', 'MAG'),('가', 'VV'), ('았', 'EPT'), ('습니다', 'EFN')]
root = [('받', 'VV')]

# %%
eval_relation(item,root)
# Out:
# 'different'

# %%
def phrase_prob(item):
        logprob = []
        i = 0
        
        while i < len(item):
            if r'.' and r',' not in item[i].keys():
                logprob.append(*item[i].values())
                i += 1
            else:
                break
            
        return np.exp(sum(logprob))

# %%
def phrase_ended(item):
    i = 0 
    ended = str()
    enders = {'ECE', 'ECS', 'EFN', 'EFQ', 'EFO', 'EFA', 'EFI', 'EFR'}
    
    while i < len(item):
        if item[i][1] in enders:
            ended = 'ended'
            break
        else:
            i += 1

    if len(ended) == 0:
        if item[-1][1] not in enders:
            ended = 'not ended'
        
    return ended

# %%
def main_gpt3_df(filename):
    """
    Sentence continuations for each prompt given in a CSV format using GPT-3.
    Compile the output and POS tags of the created tokens into a dataframe.
    """
    
    data_path = "input/{FILE}.csv".format(FILE=filename)
    df_output = pd.read_csv(data_path)
    
    token = []
    tpos = []
    cpos = []
    rel = []
    phraseprob = []
    phraseend = []
    
    with tqdm(total=df_output.shape[0]) as pbar:
        for index, row in df_output.iterrows():
        
            prompt = row['full_prompt']
            
            t = insert_gpt3(prompt)
            token.append(t['text'])
            
            token_pos = kkma.pos(t['text']) #Korean pos tagger 
            tpos.append(token_pos)
            
            cverb_pos = kkma.pos(row['context_verb'])
            cpos.append(cverb_pos)
            
            relation = eval_relation(token_pos, cverb_pos)
            rel.append(relation)
            
            phrase_p = phrase_prob(inserted_prob_gpt3(prompt))
            phraseprob.append(phrase_p)
            
            phrase_end = phrase_ended(kkma.pos(t['text']))
            phraseend.append(phrase_end)
            
            pbar.update(1)
            
    df_output['token'] = token
    df_output['token_pos'] = tpos
    df_output['cverb_pos'] = cpos
    df_output['relation'] = rel
    df_output['phrase_prob'] = phraseprob
    df_output['phrase_ended'] = phraseend

    df_output.to_csv("{TASK}_gpt3_df_output.csv".format(TASK=filename), index=False)
    
    return df_output

# %%
main_gpt3_df('subj-insert-sample')
# Out:
# 100%|█████████████████████████████████████████████| 4/4 [00:08<00:00,  2.17s/it]
#    item_id  scenario_id condition  \
# 0        1            1    nc-nom
# 1        2            1    nc-nun
# 2        3            1   nom-nom
# 3        4            1   nun-nun
#
#                                             scenario                  target  \
# 0  지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...               민찬이가 메달을
# 1  지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...               민찬이는 메달을
# 2  지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...  보미가 메달을 받았어. 민찬이가 메달을
# 3  지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...  보미는 메달을 받았어. 민찬이는 메달을
#
#               full_prompt context_verb   token  \
# 0               민찬이가 메달을            받다   받았습니다
# 1                민찬이는 메달을           받다   받았습니다
# 2  보미가 메달을 받았어. 민찬이가 메달을            받다     받았어
# 3  보미는 메달을 받았어. 민찬이는 메달을            받다  받지 못했어
#
#                                            token_pos            cverb_pos  \
# 0                    [(받, VV), (았, EPT), (습니다, EFN)]  [(받, VV), (다, EFN)]
# 1                    [(받, VV), (았, EPT), (습니다, EFN)]  [(받, VV), (다, EFN)]
# 2                      [(받, VV), (았, EPT), (어, EFN)]  [(받, VV), (다, EFN)]
# 3  [(받, VV), (지, ECD), (못하, VX), (었, EPT), (어, EFN)]  [(받, VV), (다, EFN)]
#
#      relation  phrase_prob phrase_ended
# 0    repeated     0.113311        ended
# 1    repeated     0.060011        ended
# 2    repeated     0.832638        ended
# 3  contrasted     0.392894        ended

# %%
#output = main_gpt3_df('subj-insert-full')
# Out:
# 100%|█████████████████████████████████████████| 112/112 [03:43<00:00,  2.00s/it]

# %%
#pd.set_option('display.max_rows', 500)
#output
# Out:
#      item_id  scenario_id condition  \
# 0          1            1    nc-nom
# 1          2            2    nc-nom
# 2          3            3    nc-nom
# 3          4            4    nc-nom
# 4          5            5    nc-nom
# 5          6            6    nc-nom
# 6          7            7    nc-nom
# 7          8            8    nc-nom
# 8          9            9    nc-nom
# 9         10           10    nc-nom
# 10        11           11    nc-nom
# 11        12           12    nc-nom
# 12        13           13    nc-nom
# 13        14           14    nc-nom
# 14        15           15    nc-nom
# 15        16           16    nc-nom
# 16        17           17    nc-nom
# 17        18           18    nc-nom
# 18        19           19    nc-nom
# 19        20           20    nc-nom
# 20        21           21    nc-nom
# 21        22           22    nc-nom
# 22        23           23    nc-nom
# 23        24           24    nc-nom
# 24        25           25    nc-nom
# 25        26           26    nc-nom
# 26        27           27    nc-nom
# 27        28           28    nc-nom
# 28        29            1    nc-nun
# 29        30            2    nc-nun
# 30        31            3    nc-nun
# 31        32            4    nc-nun
# 32        33            5    nc-nun
# 33        34            6    nc-nun
# 34        35            7    nc-nun
# 35        36            8    nc-nun
# 36        37            9    nc-nun
# 37        38           10    nc-nun
# 38        39           11    nc-nun
# 39        40           12    nc-nun
# 40        41           13    nc-nun
# 41        42           14    nc-nun
# 42        43           15    nc-nun
# 43        44           16    nc-nun
# 44        45           17    nc-nun
# 45        46           18    nc-nun
# 46        47           19    nc-nun
# 47        48           20    nc-nun
# 48        49           21    nc-nun
# 49        50           22    nc-nun
# 50        51           23    nc-nun
# 51        52           24    nc-nun
# 52        53           25    nc-nun
# 53        54           26    nc-nun
# 54        55           27    nc-nun
# 55        56           28    nc-nun
# 56        57            1   nom-nom
# 57        58            2   nom-nom
# 58        59            3   nom-nom
# 59        60            4   nom-nom
# 60        61            5   nom-nom
# 61        62            6   nom-nom
# 62        63            7   nom-nom
# 63        64            8   nom-nom
# 64        65            9   nom-nom
# 65        66           10   nom-nom
# 66        67           11   nom-nom
# 67        68           12   nom-nom
# 68        69           13   nom-nom
# 69        70           14   nom-nom
# 70        71           15   nom-nom
# 71        72           16   nom-nom
# 72        73           17   nom-nom
# 73        74           18   nom-nom
# 74        75           19   nom-nom
# 75        76           20   nom-nom
# 76        77           21   nom-nom
# 77        78           22   nom-nom
# 78        79           23   nom-nom
# 79        80           24   nom-nom
# 80        81           25   nom-nom
# 81        82           26   nom-nom
# 82        83           27   nom-nom
# 83        84           28   nom-nom
# 84        85            1   nun-nun
# 85        86            2   nun-nun
# 86        87            3   nun-nun
# 87        88            4   nun-nun
# 88        89            5   nun-nun
# 89        90            6   nun-nun
# 90        91            7   nun-nun
# 91        92            8   nun-nun
# 92        93            9   nun-nun
# 93        94           10   nun-nun
# 94        95           11   nun-nun
# 95        96           12   nun-nun
# 96        97           13   nun-nun
# 97        98           14   nun-nun
# 98        99           15   nun-nun
# 99       100           16   nun-nun
# 100      101           17   nun-nun
# 101      102           18   nun-nun
# 102      103           19   nun-nun
# 103      104           20   nun-nun
# 104      105           21   nun-nun
# 105      106           22   nun-nun
# 106      107           23   nun-nun
# 107      108           24   nun-nun
# 108      109           25   nun-nun
# 109      110           26   nun-nun
# 110      111           27   nun-nun
# 111      112           28   nun-nun
#
#                                               scenario  \
# 0    지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...
# 1    영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...
# 2    혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...
# 3    각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...
# 4    홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...
# 5    승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...
# 6    민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...
# 7    상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...
# 8    주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...
# 9    윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...
# 10   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...
# 11   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...
# 12   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...
# 13   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...
# 14   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...
# 15   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...
# 16   유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...
# 17   예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...
# 18   지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...
# 19   지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...
# 20   도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...
# 21   슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...
# 22   소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...
# 23   민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...
# 24   동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...
# 25   지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...
# 26   민우는 친구들과 함께 백화점을 쇼핑하기로 했습니다. 민우는 약속에 늦게나마 도착했지...
# 27   다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...
# 28   지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...
# 29   영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...
# 30   혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...
# 31   각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...
# 32   홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...
# 33   승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...
# 34   민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...
# 35   상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...
# 36   주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...
# 37   윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...
# 38   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...
# 39   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...
# 40   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...
# 41   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...
# 42   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...
# 43   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...
# 44   유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...
# 45   예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...
# 46   지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...
# 47   지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...
# 48   도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...
# 49   슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...
# 50   소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...
# 51   민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...
# 52   동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...
# 53   지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...
# 54   민우는 친구들과 함께 백화점을 쇼핑하기로 했습니다. 민우는 약속에 늦게나마 도착했지...
# 55   다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...
# 56   지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...
# 57   영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...
# 58   혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...
# 59   각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...
# 60   홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...
# 61   승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...
# 62   민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...
# 63   상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...
# 64   주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...
# 65   윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...
# 66   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...
# 67   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...
# 68   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...
# 69   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...
# 70   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...
# 71   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...
# 72   유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...
# 73   예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...
# 74   지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...
# 75   지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...
# 76   도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...
# 77   슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...
# 78   소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...
# 79   민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...
# 80   동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...
# 81   지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...
# 82   민우는 친구들과 함께 백화점을 쇼핑하기로 했습니다. 민우는 약속에 늦게나마 도착했지...
# 83   다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...
# 84   지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...
# 85   영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...
# 86   혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...
# 87   각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...
# 88   홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...
# 89   승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...
# 90   민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...
# 91   상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...
# 92   주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...
# 93   윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...
# 94   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...
# 95   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...
# 96   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...
# 97   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...
# 98   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...
# 99   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...
# 100  유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...
# 101  예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...
# 102  지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...
# 103  지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...
# 104  도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...
# 105  슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...
# 106  소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...
# 107  민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...
# 108  동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...
# 109  지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...
# 110  민우는 친구들과 함께 백화점을 쇼핑하기로 했습니다. 민우는 약속에 늦게나마 도착했지...
# 111  다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...
#
#                                      target  \
# 0                                  민찬이가 메달을
# 1                                  채영이가 집을
# 2                                 동준이가 음식을
# 3                             부산 신문이 비 소식을
# 4                             박상엽 사원이 계획서를
# 5                                  범수가 단서를
# 6                               태성이가 먹을 것을
# 7                                   건후가 공을
# 8                              이강호 작가가 관심을
# 9                                 은영이가 인기를
# 10                             태웅이가 만드는 법을
# 11                         박 후보가 새로운 교육정책을
# 12                                  민기가 길을
# 13                          가영이가 눈이 오는 날씨를
# 14                                성우가 제주도를
# 15                         재민이가 행사 홍보하는 일을
# 16                               민호 학생이 뜻을
# 17                                은찬이가 저녁을
# 18                                  민수가 돈을
# 19                              영철 씨가 거짓말을
# 20                             찬우 학생이 방정식을
# 21                                형수가 물고기를
# 22                                 정한이 조립을
# 23                                  소희가 돈을
# 24                                나영 씨가 술을
# 25                               진혁이가 이삿짐을
# 26                                 윤호가 신발을
# 27                               영환 씨가 문제를
# 28                                민찬이는 메달을
# 29                                 채영이는 집을
# 30                                동준이는 음식을
# 31                            부산 신문은 비 소식을
# 32                            박상엽 사원은 계획서를
# 33                                 범수는 단서를
# 34                              태성이는 먹을 것을
# 35                                  건후는 공을
# 36                             이강호 작가는 관심을
# 37                                은영이는 인기를
# 38                             태웅이는 만드는 법을
# 39                         박 후보는 새로운 교육정책을
# 40                                  민기는 길을
# 41                          가영이는 눈이 오는 날씨를
# 42                                성우는 제주도를
# 43                         재민이는 행사 홍보하는 일을
# 44                               민호 학생은 뜻을
# 45                                은찬이는 저녁을
# 46                                  민수는 돈을
# 47                              영철 씨는 거짓말을
# 48                             찬우 학생은 방정식을
# 49                                형수는 물고기를
# 50                                 정한은 조립을
# 51                                  소희는 돈을
# 52                                나영 씨는 술을
# 53                               진혁이는 이삿짐을
# 54                                 윤호는 신발을
# 55                               영환 씨는 문제를
# 56                   보미가 메달을 받았어. 민찬이가 메달을
# 57                    태환이가 집을 나왔어. 채영이가 집을
# 58                 시은이가 음식을 만들었어. 동준이가 음식을
# 59          서울 신문이 비 소식을 알렸어. 부산 신문이 비 소식을
# 60         김아름 사원이 계획서를 썼습니다. 박상엽 사원이 계획서를
# 61                    서희가 단서를 알았어. 범수가 단서를
# 62               현정이가 먹을 것을 줬어. 태성이가 먹을 것을
# 63                     혜정이가 공을 맞았어. 건후가 공을
# 64            박새롬 작가가 관심을 모았어. 이강호 작가가 관심을
# 65                   강우가 인기를 끌었어. 은영이가 인기를
# 66            지아가 만드는 법을 설명했어. 태웅이가 만드는 법을
# 67   김 후보가 새로운 교육정책을 주장했어. 박 후보가 새로운 교육정책을
# 68                      하나가 길을 찾았어. 민기가 길을
# 69      석현이가 눈이 오는 날씨를 즐겼어. 가영이가 눈이 오는 날씨를
# 70                  민지가 제주도를 떠났어. 성우가 제주도를
# 71     선미가 행사 홍보하는 일을 시켰어. 재민이가 행사 홍보하는 일을
# 72               혜령 학생이 뜻을 몰랐어요. 민호 학생이 뜻을
# 73                 수정이가 저녁을 먹었어요. 은찬이가 저녁을
# 74                       새봄이 돈을 냈어. 민수가 돈을
# 75              선희 씨가 거짓말을 믿었어. 영철 씨가 거짓말을
# 76          승연 학생이 방정식을 이해했어요. 찬우 학생이 방정식을
# 77                  다혜가 물고기를 잡았어. 형수가 물고기를
# 78                   승철이 조립을 가르쳤어. 정한이 조립을
# 79                    민수가 돈을 요구했어요. 소희가 돈을
# 80                 은호 씨가 술을 거부했어. 나영 씨가 술을
# 81               하윤이가 이삿짐을 들었어요. 진혁이가 이삿짐을
# 82                     현주가 신발을 샀어. 윤호가 신발을
# 83               지현 씨가 문제를 제기했어. 영환 씨가 문제를
# 84                   보미는 메달을 받았어. 민찬이는 메달을
# 85                    태환이는 집을 나왔어. 채영이는 집을
# 86                 시은이는 음식을 만들었어. 동준이는 음식을
# 87          서울 신문은 비 소식을 알렸어. 부산 신문은 비 소식을
# 88         김아름 사원은 계획서를 썼습니다. 박상엽 사원은 계획서를
# 89                    서희는 단서를 알았어. 범수는 단서를
# 90               현정이는 먹을 것을 줬어. 태성이는 먹을 것을
# 91                     혜정이는 공을 맞았어. 건후는 공을
# 92            박새롬 작가는 관심을 모았어. 이강호 작가는 관심을
# 93                   강우는 인기를 끌었어. 은영이는 인기를
# 94            지아는 만드는 법을 설명했어. 태웅이는 만드는 법을
# 95   김 후보는 새로운 교육정책을 주장했어. 박 후보는 새로운 교육정책을
# 96                      하나는 길을 찾았어. 민기는 길을
# 97      석현이는 눈이 오는 날씨를 즐겼어. 가영이는 눈이 오는 날씨를
# 98                  민지는 제주도를 떠났어. 성우는 제주도를
# 99     선미는 행사 홍보하는 일을 시켰어. 재민이는 행사 홍보하는 일을
# 100              혜령 학생은 뜻을 몰랐어요. 민호 학생은 뜻을
# 101                수정이는 저녁을 먹었어요. 은찬이는 저녁을
# 102                      새봄은 돈을 냈어. 민수는 돈을
# 103             선희 씨는 거짓말을 믿었어. 영철 씨는 거짓말을
# 104         승연 학생은 방정식을 이해했어요. 찬우 학생은 방정식을
# 105                 다혜는 물고기를 잡았어. 형수는 물고기를
# 106                  승철은 조립을 가르쳤어. 정한은 조립을
# 107                   민수는 돈을 요구했어요. 소희는 돈을
# 108                은호 씨는 술을 거부했어. 나영 씨는 술을
# 109              하윤이는 이삿짐을 들었어요. 진혁이는 이삿짐을
# 110                    현주는 신발을 샀어. 윤호는 신발을
# 111              지현 씨는 문제를 제기했어. 영환 씨는 문제를
#
#                                            full_prompt context_verb  \
# 0    지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...           받다
# 1    영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...          나오다
# 2    혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...          만들다
# 3    각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...          알리다
# 4    홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...           쓰다
# 5    승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...           알다
# 6    민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...           주다
# 7    상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...           맞다
# 8    주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...          모으다
# 9    윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...           끌다
# 10   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...         설명하다
# 11   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...         주장하다
# 12   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...           찾다
# 13   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...          즐기다
# 14   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...          떠나다
# 15   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...          시키다
# 16   유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...          모르다
# 17   예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...           먹다
# 18   지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...           내다
# 19   지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...           믿다
# 20   도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...         이해하다
# 21   슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...           잡다
# 22   소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...         가르치다
# 23   민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...         요구하다
# 24   동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...         거부하다
# 25   지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...           들다
# 사다
# 27   다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...         제기하다
# 28   지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...           받다
# 29   영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...          나오다
# 30   혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...          만들다
# 31   각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...          알리다
# 32   홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...           쓰다
# 33   승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...           알다
# 34   민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...           주다
# 35   상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...           맞다
# 36   주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...          모으다
# 37   윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...           끌다
# 38   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...         설명하다
# 39   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...         주장하다
# 40   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...           찾다
# 41   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...          즐기다
# 42   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...          떠나다
# 43   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...          시키다
# 44   유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...          모르다
# 45   예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...           먹다
# 46   지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...           내다
# 47   지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...           믿다
# 48   도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...         이해하다
# 49   슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...           잡다
# 50   소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...         가르치다
# 51   민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...         요구하다
# 52   동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...         거부하다
# 53   지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...           들다
# 사다
# 55   다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...         제기하다
# 56   지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...           받다
# 57   영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...          나오다
# 58   혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...          만들다
# 59   각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...          알리다
# 60   홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...           쓰다
# 61   승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...           알다
# 62   민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...           주다
# 63   상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...           맞다
# 64   주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...          모으다
# 65   윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...           끌다
# 66   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...         설명하다
# 67   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...         주장하다
# 68   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...           찾다
# 69   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...          즐기다
# 70   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...          떠나다
# 71   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...          시키다
# 72   유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...          모르다
# 73   예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...           먹다
# 74   지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...           내다
# 75   지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...           믿다
# 76   도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...         이해하다
# 77   슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...           잡다
# 78   소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...         가르치다
# 79   민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...         요구하다
# 80   동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...         거부하다
# 81   지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...           들다
# 사다
# 83   다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...         제기하다
# 84   지은이 친구들 다섯 명과 함께 마라톤 경주에 참여했습니다. 지은은 다른 약속이 있어...           받다
# 85   영준과 은지는 다른 세 명의 친구들과 함께 오후 5시에 만나기로 약속했습니다. 영준...          나오다
# 86   혜미와 혜미의 친구들이 연말 파티를 하기로 했습니다. 몇몇 친구들은 음식을 준비하고...          만들다
# 87   각 지역 신문은 매일 일기 예보 기사를 전합니다. 민준이 아현에게 오늘의 일기 예보...          알리다
# 88   홍보팀장이 다섯 명의 팀원들로부터 전달받은 프로젝트 보고서를 연구팀에 보냈습니다. ...           쓰다
# 89   승우가 친구들과 함께 온라인 추리 게임을 했습니다. 승우는 범인이 누구라고 생각하는...           알다
# 90   민아와 상현이가 유기견을 돕는 봉사활동을 하고 있습니다. 민아는 교실 앞에 기부함을...           주다
# 91   상훈이 친구들과 함께 피구게임을 했고 혜미는 게임을 하지 않았습니다. 상훈은 게임 ...           맞다
# 92   주희가 여러 명의 미술 작가들이 참여한 전시회에 구경을 갔지만 마감 시간이 되어서 ...          모으다
# 93   윤지가 친구들의 연극 공연을 보러 갔습니다. 윤지는 공연에 늦게나마 도착했지만 도현...           끌다
# 94   효섭과 은혜는 다른 세 명의 친구들과 함께 크리스마스 케익을 만들기로 했습니다. 효...         설명하다
# 95   오늘은 세 대통령 후보들의 연설이 있는 날입니다. 하연은 늦게나마 텔레비전을 켜고 ...         주장하다
# 96   석준과 경아가 새 집으로 이사를 했습니다. 석준과 경아는 여섯 명의 친구들을 집들이...           찾다
# 97   상혁이가 친구들 다섯 명과 함께 스키장으로 휴가를 떠났습니다. 상혁은 감기 증상이 ...          즐기다
# 98   지혜와 연우는 제주도 출신이지만 지금은 서울에 살고 있습니다. 연우는 지혜에게 다른...          떠나다
# 99   석진과 다섯 명의 학생회 학생들이 학교 행사 준비를 맡았습니다. 행사 준비 첫째 날...          시키다
# 100  유진과 민식은 학생들에게 영어를 가르치고 있습니다. 오늘 유진은 학생들이 어려워하는...          모르다
# 101  예지가 집에 막 도착하려던 참이었습니다. 예지의 어머니가 예지에게 가족들이 먹을 김...           먹다
# 102  지영은 친구들 다섯 명과 함께 점심을 먹었습니다. 지영은 가장 먼저 식사 자리를 떠...           내다
# 103  지난 회의에 참석하지 못했던 용석은 몸이 아팠다고 둘러댔습니다. 이후 동우는 희연에...           믿다
# 104  도환과 유나는 학교에서 수학을 가르치고 있습니다. 오늘 도환은 학생들이 모두 어려워...         이해하다
# 105  슬기가 네 명의 친구들과 함께 캠핑을 다녀왔습니다. 슬기는 혼자 등산을 했고 나머지...           잡다
# 106  소희의 친구들 세 명이 힘을 합쳐 가구를 조립했고 소희는 늦게 도착해서 조립을 마무...         가르치다
# 107  민영과 민영의 친구들 세 명이 같은 차를 타던 중 교통 사고를 당했습니다. 민영의 ...         요구하다
# 108  동민은 직장 동료들과 함께 회식을 했습니다. 동민은 회식 자리를 일찍 떴고 유미는 ...         거부하다
# 109  지연이 이사하기 하루 전날 다리를 다쳤습니다. 지연의 친구들 네 명이 지연이가 이사...           들다
# 사다
# 111  다섯 명의 팀원들이 회의를 가졌습니다. 용규는 회의에 늦게나마 도착했지만 민정은 회...         제기하다
#
#                                                  token  \
# 0                                       얻었고, 영훈이는 두 번째
# 1                                       빠져서 늦게 왔고, 소연이
# 2                                         준비했고, 지연이가 파
# 3                                             전하고 있습니다
# 4                                        작성하고, 이승호 사원이
# 5                                            모두 찾아냈습니다
# 6                                        기부했고, 지연이가 놀이
# 7                                    \n\n"건후가 공을 치고 이겼
# 8                                                  끌었어
# 9                                               많이 받았어
# 10                                       설명하고 있었고, 나는
# 11                                       제시했고, 이 후보가 인
# 12   \n\nMin-gi is the last one to arrive, but ever...
# 13                                       좋아하고, 스키를 타는
# 14                                       떠나서 서울에 살고 있습
# 15                                       맡았고, 지원이가 각 부
# 16                                  \n\n민호 학생이 뜻을 잘 이해
# 17                                       \n\n먹기 위해 왔어요
# 18                                       가져왔고, 영희는 치킨을
# 19                                      한 것 같아서 당황하고 있
# 20                                    \n\nIt went well
# 21                                         ___ 하고 있었어요
# 22                                        시작했고, 영희가 마무
# 23                                       받고 싶지 않고, 소희가
# 24                                       많이 마셨는데 너무 재밌
# 25                                    , 소영이가 책상을 , 승현이
# 26         \n\nIt was fun! We all got some great deals
# 27                     \n\nIt was a productive meeting
# 28                                      얻었고, 영훈이는 두 번째
# 29                                     \n\n아직 떠나지 않았어요
# 30                                       , 소연이는 파티 장소를
# 31                                    \n\n비가 오지 않을 것으로
# 32                                       작성하고, 김영희 사원은
# 33                     \n\nI think the suspect is John
# 34                                       기부했고, 지연이는 장난
# 35                                    \n\n건후가 공을 잡아서 이
# 36                                     \n\n이강호 작가는 관심을
# 37                   \n\nEunyoung was the most popular
# 38                                      설명하고 있고, 소연이는
# 39                                       제시했고, 이 후보는 경
# 40                                       잘 찾아왔고, 영희는 아
# 41                                                좋아해요
# 42                                       떠나 서울에 살고 있고,
# 43                                     , 소연이는 각 부문 준비하
# 44                                  \n\n민호 학생은 뜻을 잘 이해
# 45                                        \n\n먹지 않겠습니다
# 46                                        가져왔고, 영희는 맛있
# 47                                             한 것 같아요
# 48   \n\nThe students found the equation difficult,...
# 49                                          ___ 개 잡았어요
# 50                                       시작하고, 영희는 마무리
# 51                                     , 소영은 의료비를 , 민영
# 52                                       잘 못 마시는 거 같았어
# 53                 \n\nJinhyuk carried the heavy boxes
# 54                                   \n\n구매했고, 나는 옷을 구
# 55                           \n\nThe meeting went well
# 56                                                 받았어
# 57                                               \n나왔어
# 58                                                가져왔어
# 59                                    \n\n부산 신문도 비가 오겠
# 60                                       리뷰했고, 이승호 사원이
# 61                                    \n\n범인이 누구라고 생각하
# 62                                    \n\n태성이가 먹을 것과 장
# 63                                         \n\n맞추어 이겼어
# 64                                                 모았어
# 65                                                 끌었어
# 66                                   \n\n제이가 만드는 법을 설명
# 67                                                강조했어
# 68                                                 ___
# 69                                        좋아해서 스키를 타는
# 70                                                 떠났어
# 71                                                 시켰어
# 72                                             잘 이해했어요
# 73                                          \n\n안 먹었어요
# 74                                                  냈어
# 75                                              믿지 않았어
# 76                                         ___ 하고 있었어요
# 77                                                 잡았어
# 78                                      하고 있었고, 나는 마무리
# 79                                       요구하지 않고 사과만 요
# 80                     마시고 있었고,\n\nIt was a lot of fun
# 81                                          들고 방으로 갔어요
# 82                                          ___ 가지고 왔어
# 83                                       해결하는 방법을 제시했어
# 84                                            ___ 가져갔어
# 85                                      \n나왔고, 승현이는 아직
# 86                                                가져왔어
# 87                                             \n\n알렸어
# 88                                       리뷰했고, 이승호 사원은
# 89                                   \n\n내가 생각하는 범인이 맞
# 90                                    \n\n현정이는 사료를, 태성
# 91                                    \n\n건후는 공을 놓치고 말
# 92       \n\nPark Saerom's work was definitely popular
# 93                                                 끌었어
# 94                                       실습했고, 나는 마무리하
# 95                                       제시했고, 이 후보는 교
# 96   \n\nMin-gi is still looking for the way, but t...
# 97                                        좋아해서 스키를 타는
# 98                                       떠나지 않고 여전히 제주
# 99                                                 시켰어
# 100                                      \n\n확실히 이해했어요
# 101                                         \n\n안 먹었어요
# 102                                           \n\n못 냈어
# 103                                             믿지 않았어
# 104                                        ___ 하고 있었어요
# 105                                      잡지 못했지만 놀라운 사
# 106                                          하는 것을 도왔어
# 107                                      요구하지 않고 사과만 요
# 108                                            \n\n마셨어
# 109                                              가져갔어요
# 110                                             ___ 했어
# 111                                         해결하려고 노력했어
#
#                                              token_pos  \
# 0    [(얻, VV), (었, EPT), (고, ECE), (,, SP), (영, NNG...
# 1    [(빠지, VV), (어서, ECD), (늦, VA), (게, ECD), (오, V...
# 2    [(준비, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...
# 3           [(전하, VV), (고, ECE), (있, VXV), (습니다, EFN)]
# 4    [(작성, NNG), (하, XSV), (고, ECE), (,, SP), (이승, ...
# 5         [(모두, MAG), (찾아내, VV), (었, EPT), (습니다, EFN)]
# 6    [(기부, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...
# 7    [(", SS), (건, NNM), (후, NNG), (가, JKS), (공, NN...
# 8                        [(끌, VV), (었, EPT), (어, EFN)]
# 9             [(많이, MAG), (받, VV), (았, EPT), (어, EFN)]
# 10   [(설명, NNG), (하, XSV), (고, ECE), (있었, VV), (고, ...
# 11   [(제시, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...
# 12   [(Min-gi, OL), (is, OL), (the, OL), (last, OL)...
# 13   [(좋아하, VV), (고, ECE), (,, SP), (스키, NNG), (를, ...
# 14   [(떠나, VV), (서, ECD), (서울, NNG), (에, JKM), (살, ...
# 15   [(맡, VV), (았, EPT), (고, ECE), (,, SP), (지원, NN...
# 16   [(민호, NNG), (학생, NNG), (이, JKS), (뜻, NNG), (을,...
# 17   [(먹, VV), (기, ETN), (위하, VV), (어, ECS), (오, VV...
# 18   [(가져오, VV), (았, EPT), (고, ECE), (,, SP), (영희, ...
# 19   [(하, VV), (ㄴ, ETD), (것, NNB), (같, VA), (아서, EC...
# 20                  [(It, OL), (went, OL), (well, OL)]
# 21   [(___, SW), (하, VV), (고, ECE), (있, VV), (었, EP...
# 22   [(시작하, VV), (었, EPT), (고, ECE), (,, SP), (영희, ...
# 23   [(받, VV), (고, ECE), (싶, VXA), (지, ECD), (않, VX...
# 24   [(많이, MAG), (마시, VV), (었, EPT), (는데, ECD), (너무...
# 25   [(,, SP), (소영이, NNG), (가, JKS), (책상, NNG), (을,...
# 26   [(It, OL), (was, OL), (fun, OL), (!, SF), (We,...
# 27   [(It, OL), (was, OL), (a, OL), (productive, OL...
# 28   [(얻, VV), (었, EPT), (고, ECE), (,, SP), (영, NNG...
# 29   [(아직, MAG), (떠나, VV), (지, ECD), (않, VXV), (았, ...
# 30   [(,, SP), (소연, NNG), (이, JKS), (늘, VV), (ㄴ, ET...
# 31   [(비가, NNG), (오, VV), (지, ECD), (않, VXV), (을, E...
# 32   [(작성, NNG), (하, XSV), (고, ECE), (,, SP), (김영희,...
# 33   [(I, OL), (think, OL), (the, OL), (suspect, OL...
# 34   [(기부, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...
# 35   [(걸, VV), (ㄴ, ETD), (후, NNG), (가, JKS), (공, NN...
# 36   [(이, MDT), (강호, NNG), (작가, NNG), (는, JX), (관심,...
# 37   [(Eunyoung, OL), (was, OL), (the, OL), (most, ...
# 38   [(설명, NNG), (하, XSV), (고, ECE), (있, VXV), (고, ...
# 39   [(제시, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...
# 40   [(잘, MAG), (찾아오, VV), (았, EPT), (고, ECE), (,, ...
# 41                              [(좋아하, VV), (어요, EFN)]
# 42   [(떨, VV), (나, ECE), (서울, NNG), (에, JKM), (살, V...
# 43   [(,, SP), (소연, NNG), (이, JKS), (늘, VV), (ㄴ, ET...
# 44   [(민호, NNG), (학생, NNG), (은, JX), (뜻, NNG), (을, ...
# 45   [(먹, VV), (지, ECD), (않, VXV), (겠, EPT), (습니다, ...
# 46   [(가져오, VV), (았, EPT), (고, ECE), (,, SP), (영희, ...
# 47   [(하, VV), (ㄴ, ETD), (것, NNB), (같, VA), (아요, EFN)]
# 48   [(The, OL), (students, OL), (found, OL), (the,...
# 49   [(___, SW), (개, NNG), (잡, VV), (았, EPT), (어요, ...
# 50   [(시작, NNG), (하, XSV), (고, ECE), (,, SP), (영희, ...
# 51   [(,, SP), (소, XPN), (영, NNG), (은, JX), (의료비, N...
# 52   [(잘, MAG), (못, MAG), (마시, VV), (는, ETD), (거, N...
# 53   [(Jinhyuk, OL), (carried, OL), (the, OL), (hea...
# 54   [(구매, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...
# 55   [(The, OL), (meeting, OL), (went, OL), (well, ...
# 56                       [(받, VV), (았, EPT), (어, EFN)]
# 57                      [(나오, VV), (았, EPT), (어, EFN)]
# 58                     [(가져오, VV), (았, EPT), (어, EFN)]
# 59   [(부산, NNG), (신문, NNG), (도, JX), (비, NNG), (가, ...
# 60   [(리뷰, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...
# 61   [(범인, NNG), (이, JKS), (누구, NP), (라고, JX), (생각,...
# 62   [(태성, NNG), (이, JKS), (가, VV), (아, ECS), (먹, V...
# 63   [(맞추, VV), (어, ECD), (이기, VV), (었, EPT), (어, E...
# 64                      [(모으, VV), (았, EPT), (어, EFN)]
# 65                       [(끌, VV), (었, EPT), (어, EFN)]
# 66   [(제이, NNG), (가, JKS), (만들, VV), (는, ETD), (법, ...
# 67                     [(강조하, VV), (었, EPT), (어, EFN)]
# 68                                         [(___, SW)]
# 69   [(좋아하, VV), (어서, ECD), (스키, NNG), (를, JKO), (타...
# 70                      [(떠나, VV), (었, EPT), (어, EFN)]
# 71                                [(시켰, VV), (어, ECD)]
# 72   [(잘, MAG), (이해, NNG), (하, XSV), (었, EPT), (어요,...
# 73            [(안, MAG), (먹, VV), (었, EPT), (어요, EFN)]
# 74                       [(내, VV), (었, EPT), (어, EFN)]
# 75   [(믿, VV), (지, ECD), (않, VXV), (았, EPT), (어, EFN)]
# 76   [(___, SW), (하, VV), (고, ECE), (있, VV), (었, EP...
# 77                       [(잡, VV), (았, EPT), (어, EFN)]
# 78   [(하, VV), (고, ECE), (있었, VV), (고, ECE), (,, SP...
# 79   [(요구, NNG), (하, XSV), (지, ECD), (않, VXV), (고, ...
# 80   [(마시, VV), (고, ECE), (있었, VV), (고, ECE), (,, S...
# 81   [(들, VV), (고, ECE), (방, NNG), (으로, JKM), (가, V...
# 82   [(___, SW), (가지, VV), (고, ECE), (오, VV), (았, E...
# 83   [(해결, NNG), (하, XSV), (는, ETD), (방법, NNG), (을,...
# 84          [(___, SW), (가져가, VV), (었, EPT), (어, EFN)]
# 85   [(나오, VV), (았, EPT), (고, ECE), (,, SP), (승, NN...
# 86                     [(가져오, VV), (았, EPT), (어, EFN)]
# 87                      [(알리, VV), (었, EPT), (어, EFN)]
# 88   [(리뷰, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...
# 89   [(내가, NNG), (생각, NNG), (하, XSV), (는, ETD), (범인...
# 90   [(현정이, NNG), (는, JX), (사료, NNG), (를, JKO), (,,...
# 91   [(걸, VV), (ㄴ, ETD), (후, NNG), (는, JX), (공, NNG...
# 92   [(Park, OL), (Saerom, OL), (', SS), (s, OL), (...
# 93                       [(끌, VV), (었, EPT), (어, EFN)]
# 94   [(실습, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...
# 95   [(제시, NNG), (하, XSV), (었, EPT), (고, ECE), (,, ...
# 96   [(Min-gi, OL), (is, OL), (still, OL), (looking...
# 97   [(좋아하, VV), (어서, ECD), (스키, NNG), (를, JKO), (타...
# 98   [(떠나, VV), (지, ECD), (않, VXV), (고, ECE), (여전히,...
# 99                                [(시켰, VV), (어, ECD)]
# 100  [(확실히, MAG), (이해, NNG), (하, XSV), (었, EPT), (어...
# 101           [(안, MAG), (먹, VV), (었, EPT), (어요, EFN)]
# 102            [(못, MAG), (내, VV), (었, EPT), (어, EFN)]
# 103  [(믿, VV), (지, ECD), (않, VXV), (았, EPT), (어, EFN)]
# 104  [(___, SW), (하, VV), (고, ECE), (있, VV), (었, EP...
# 105  [(잡, VV), (지, ECD), (못하, VX), (었, EPT), (지만, E...
# 106  [(하, VV), (는, ETD), (것, NNB), (을, JKO), (돕, VV...
# 107  [(요구, NNG), (하, XSV), (지, ECD), (않, VXV), (고, ...
# 108                     [(마시, VV), (었, EPT), (어, EFN)]
# 109                   [(가져가, VV), (었, EPT), (어요, EFN)]
# 110           [(___, SW), (하, VV), (었, EPT), (어, EFN)]
# 111  [(해결, NNG), (하, XSV), (려고, ECD), (노력, NNG), (하...
#
#                            cverb_pos    relation  phrase_prob phrase_ended
# 0                [(받, VV), (다, EFN)]   different     0.195460        ended
# 1               [(나오, VV), (다, EFN)]   different     0.003906        ended
# 2               [(만들, VV), (다, EFN)]   different     0.681167        ended
# 3               [(알리, VV), (다, EFN)]   different     0.108936        ended
# 4                [(쓰, VV), (다, EFN)]   different     0.380932        ended
# 5                [(알, VV), (다, EFN)]   different     0.000779        ended
# 6               [(주, VXV), (다, EFN)]   different     0.623868        ended
# 7                         [(맞닿, VV)]   different     0.004099        ended
# 8               [(모으, VV), (다, EFN)]   different     0.025594        ended
# 9                [(끌, VV), (다, EFN)]   different     0.016221        ended
# 10   [(설명, NNG), (하, XSA), (다, EFN)]    repeated     0.013030        ended
# 11   [(주장, NNG), (하, XSA), (다, EFN)]   different     0.182860        ended
# 12               [(찾, VV), (다, EFN)]   different     0.000973    not ended
# 13              [(즐기, VV), (다, EFN)]   different     0.044528        ended
# 14              [(떠나, VV), (다, EFN)]    repeated     0.001007        ended
# 15              [(시키, VV), (다, EFN)]   different     0.190981        ended
# 16              [(모르, VV), (다, EFN)]   different     0.056472    not ended
# 17               [(먹, VV), (다, EFN)]    repeated     0.000158        ended
# 18                        [(내달, VV)]   different     0.057611        ended
# 19               [(믿, VV), (다, EFN)]   different     0.000271        ended
# 20            [(이해, NNG), (하다, NNP)]   different     0.060693    not ended
# 21                        [(잡다, XR)]   different     0.001422        ended
# 22             [(가르치, VV), (다, EFN)]   different     0.203366        ended
# 23            [(요구, NNG), (하다, NNP)]   different     0.006517        ended
# 24   [(거부, NNG), (하, XSA), (다, EFN)]   different     0.000023    not ended
# 25               [(들, VV), (다, EFN)]   different     1.000000    not ended
# 26               [(사, VV), (다, EFN)]   different     0.000157    not ended
# 27            [(제기, NNG), (하다, NNP)]   different     0.020654    not ended
# 28               [(받, VV), (다, EFN)]   different     0.155620        ended
# 29              [(나오, VV), (다, EFN)]   different     0.001526        ended
# 30              [(만들, VV), (다, EFN)]   different     1.000000    not ended
# 31              [(알리, VV), (다, EFN)]   different     0.016021    not ended
# 32               [(쓰, VV), (다, EFN)]   different     0.113631        ended
# 33               [(알, VV), (다, EFN)]   different     0.015953    not ended
# 34              [(주, VXV), (다, EFN)]   different     0.526995        ended
# 35                        [(맞닿, VV)]   different     0.001024    not ended
# 36              [(모으, VV), (다, EFN)]   different     0.043506    not ended
# 37               [(끌, VV), (다, EFN)]   different     0.031088    not ended
# 38   [(설명, NNG), (하, XSA), (다, EFN)]    repeated     0.003148        ended
# 39   [(주장, NNG), (하, XSA), (다, EFN)]   different     0.137892        ended
# 40               [(찾, VV), (다, EFN)]   different     0.067777        ended
# 41              [(즐기, VV), (다, EFN)]   different     0.096853        ended
# 42              [(떠나, VV), (다, EFN)]   different     0.007141        ended
# 43              [(시키, VV), (다, EFN)]   different     1.000000    not ended
# 44              [(모르, VV), (다, EFN)]   different     0.157623    not ended
# 45               [(먹, VV), (다, EFN)]  contrasted     0.002352        ended
# 46                        [(내달, VV)]   different     0.024202        ended
# 47               [(믿, VV), (다, EFN)]   different     0.019925        ended
# 48            [(이해, NNG), (하다, NNP)]   different     0.007802    not ended
# 49                        [(잡다, XR)]   different     0.006025        ended
# 50             [(가르치, VV), (다, EFN)]   different     0.120860        ended
# 51            [(요구, NNG), (하다, NNP)]   different     1.000000    not ended
# 52   [(거부, NNG), (하, XSA), (다, EFN)]   different     0.000066        ended
# 53               [(들, VV), (다, EFN)]   different     0.018696    not ended
# 54               [(사, VV), (다, EFN)]   different     0.019978        ended
# 55            [(제기, NNG), (하다, NNP)]   different     0.056005    not ended
# 56               [(받, VV), (다, EFN)]    repeated     0.361095        ended
# 57              [(나오, VV), (다, EFN)]    repeated     0.074153        ended
# 58              [(만들, VV), (다, EFN)]   different     0.212346        ended
# 59              [(알리, VV), (다, EFN)]   different     0.012682    not ended
# 60               [(쓰, VV), (다, EFN)]   different     0.065649        ended
# 61               [(알, VV), (다, EFN)]   different     0.002438    not ended
# 62              [(주, VXV), (다, EFN)]   different     0.008851        ended
# 63                        [(맞닿, VV)]   different     0.003791        ended
# 64              [(모으, VV), (다, EFN)]    repeated     0.282263        ended
# 65               [(끌, VV), (다, EFN)]    repeated     0.190849        ended
# 66   [(설명, NNG), (하, XSA), (다, EFN)]    repeated     0.001726    not ended
# 67   [(주장, NNG), (하, XSA), (다, EFN)]   different     0.045314        ended
# 68               [(찾, VV), (다, EFN)]   different     0.262358    not ended
# 69              [(즐기, VV), (다, EFN)]   different     0.000291    not ended
# 70              [(떠나, VV), (다, EFN)]    repeated     0.373792        ended
# 71              [(시키, VV), (다, EFN)]   different     0.536075    not ended
# 72              [(모르, VV), (다, EFN)]   different     0.094436        ended
# 73               [(먹, VV), (다, EFN)]  contrasted     0.112370        ended
# 74                        [(내달, VV)]   different     0.201496        ended
# 75               [(믿, VV), (다, EFN)]  contrasted     0.189034        ended
# 76            [(이해, NNG), (하다, NNP)]   different     0.003580        ended
# 77                        [(잡다, XR)]   different     0.045196        ended
# 78             [(가르치, VV), (다, EFN)]   different     0.113655        ended
# 79            [(요구, NNG), (하다, NNP)]  contrasted     0.002359        ended
# 80   [(거부, NNG), (하, XSA), (다, EFN)]   different     0.001683        ended
# 81               [(들, VV), (다, EFN)]    repeated     0.001672        ended
# 82               [(사, VV), (다, EFN)]   different     0.004305        ended
# 83            [(제기, NNG), (하다, NNP)]   different     0.007958        ended
# 84               [(받, VV), (다, EFN)]   different     0.019055        ended
# 85              [(나오, VV), (다, EFN)]    repeated     0.016016        ended
# 86              [(만들, VV), (다, EFN)]   different     0.130330        ended
# 87              [(알리, VV), (다, EFN)]    repeated     0.060519        ended
# 88               [(쓰, VV), (다, EFN)]   different     0.125824        ended
# 89               [(알, VV), (다, EFN)]   different     0.009219    not ended
# 90              [(주, VXV), (다, EFN)]   different     0.144398    not ended
# 91                        [(맞닿, VV)]   different     0.001130        ended
# 92              [(모으, VV), (다, EFN)]   different     0.059808    not ended
# 93               [(끌, VV), (다, EFN)]    repeated     0.042976        ended
# 94   [(설명, NNG), (하, XSA), (다, EFN)]   different     0.008839        ended
# 95   [(주장, NNG), (하, XSA), (다, EFN)]   different     0.025324        ended
# 96               [(찾, VV), (다, EFN)]   different     0.026345    not ended
# 97              [(즐기, VV), (다, EFN)]   different     0.000489    not ended
# 98              [(떠나, VV), (다, EFN)]  contrasted     0.008907        ended
# 99              [(시키, VV), (다, EFN)]   different     0.179915    not ended
# 100             [(모르, VV), (다, EFN)]   different     0.038243        ended
# 101              [(먹, VV), (다, EFN)]  contrasted     0.089657        ended
# 102                       [(내달, VV)]   different     0.046381        ended
# 103              [(믿, VV), (다, EFN)]  contrasted     0.194724        ended
# 104           [(이해, NNG), (하다, NNP)]   different     0.005458        ended
# 105                       [(잡다, XR)]   different     0.001886        ended
# 106            [(가르치, VV), (다, EFN)]   different     0.009865        ended
# 107           [(요구, NNG), (하다, NNP)]  contrasted     0.001943        ended
# 108  [(거부, NNG), (하, XSA), (다, EFN)]   different     0.003898        ended
# 109              [(들, VV), (다, EFN)]   different     0.041867        ended
# 110              [(사, VV), (다, EFN)]   different     0.025564        ended
# 111           [(제기, NNG), (하다, NNP)]   different     0.015780        ended

# %% [markdown]
# ## To do/Notes
#
# 0. Anomaly in POS tagger
# - row105 [(잡다, XR)] in cverb_pos, [(잡, VV)] in token_pos
#
# 1. Phrase ending vs. Sentence ending: what is more important for evaluation?
# - We need to be able to know whether the non-contrastive relation is from tokens not having the verb or the generated verb token is actually non-contrastive
#
# - Add eval_VP to check whether the output is a grammatical VP.
#
#
# 2. We can increase the max length enough that sentence endings are likely to appear, but this is an additional constraint we will feed in that we don't have to in human cloze tasks (Humans respond with one or two words without an additional instruction).
# - Reflecting this, in stat analysis, we can only consider cases where phrase/sentence ending was present. If the sentence is not ended, GPT-3 results are not like human's cloze test, where people are likely to have the simpliest/shortest VP to end the sentence.
